# %%
import pandas as pd
import matplotlib
import numpy as np

# %%
data=pd.read_csv("station_belem.csv")

# %%
data.head(5)
# Out:
#    YEAR     JAN     FEB     MAR     APR     MAY     JUN     JUL     AUG  \
# 0  1961   26.43   25.53   25.88   26.07   26.31   26.64   26.77   26.72
# 1  1962   26.30   26.06   26.15   26.04   26.83   26.74   26.71   26.94
# 2  1963   26.25   26.03   26.02   26.42   27.17   26.94   26.93   26.98
# 3  1964   25.70   25.52   25.41   25.75   26.55   26.91   27.16   27.34
# 4  1965  999.90  999.90  999.90  999.90  999.90  999.90  999.90  999.90
#
#       SEP     OCT     NOV     DEC
# 0   26.62   26.46   26.50   26.51
# 1   26.87   26.80   26.68   26.91
# 2   26.96   26.85   27.06   26.24
# 3   27.32  999.90  999.90  999.90
# 4  999.90  999.90  999.90  999.90

# %%
transposed_df = data.set_index('YEAR').T
transposed_df.head()
# Out:
# YEAR   1961   1962   1963   1964   1965   1966   1967    1968   1969   1970  \
# JAN   26.43  26.30  26.25  25.70  999.9  999.9  26.55   25.99  26.64  26.70
# FEB   25.53  26.06  26.03  25.52  999.9  999.9  25.99  999.90  27.11  26.99
# MAR   25.88  26.15  26.02  25.41  999.9  999.9  25.93   25.74  27.34  26.63
# APR   26.07  26.04  26.42  25.75  999.9  999.9  26.24  999.90  27.58  27.11
# MAY   26.31  26.83  27.17  26.55  999.9  999.9  26.33  999.90  27.90  27.16
#
# YEAR  ...   2010   2011   2012   2013   2014    2015    2016   2017   2018  \
# JAN   ...  27.65  999.9  27.74  28.28  27.87   27.82  999.90  27.51  27.86
# FEB   ...  28.30  999.9  27.04  27.98  27.72   27.62   28.22  27.36  27.26
# MAR   ...  29.05  999.9  27.34  28.08  27.92  999.90   28.32  27.11  28.11
# APR   ...  28.20  999.9  28.04  28.33  27.97  999.90   28.87  27.71  27.81
# MAY   ...  28.84  999.9  27.89  28.33  27.97  999.90   28.72  28.61  28.21
#
# YEAR   2019
# JAN   27.60
# FEB   27.20
# MAR   27.35
# APR   27.90
# MAY   28.40
#
# [5 rows x 59 columns]

# %%
a = list(data.YEAR)
d=pd.DataFrame()
for ind, i in enumerate(a):
    for x in range(12):
        d[ind,x]=[i,transposed_df.iloc[x,ind]]
# Out:
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# ...
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3504310048.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   d[ind,x]=[i,transposed_df.iloc[x,ind]]

# %%
t_df=d.T
t_df.head(112)
# Out:
#               0      1
# (0, 0)   1961.0  26.43
# (0, 1)   1961.0  25.53
# (0, 2)   1961.0  25.88
# (0, 3)   1961.0  26.07
# (0, 4)   1961.0  26.31
# ...         ...    ...
# (8, 11)  1969.0  27.56
# (9, 0)   1970.0  26.70
# (9, 1)   1970.0  26.99
# (9, 2)   1970.0  26.63
# (9, 3)   1970.0  27.11
#
# [112 rows x 2 columns]

# %%
t_df.head(112)
# Out:
#               0      1
# (0, 0)   1961.0  26.43
# (0, 1)   1961.0  25.53
# (0, 2)   1961.0  25.88
# (0, 3)   1961.0  26.07
# (0, 4)   1961.0  26.31
# ...         ...    ...
# (8, 11)  1969.0  27.56
# (9, 0)   1970.0  26.70
# (9, 1)   1970.0  26.99
# (9, 2)   1970.0  26.63
# (9, 3)   1970.0  27.11
#
# [112 rows x 2 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.tsatools import lagmat

import matplotlib.pyplot as plt

# settings
plt.style.use("seaborn")
plt.rcParams["figure.figsize"] = (16, 8)
# Out:
# C:\Users\sudha\AppData\Local\Temp\ipykernel_1708\3399831573.py:12: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
y=t_df[1]

# %%
fig, ax = plt.subplots(2, 1)

plot_acf(t_df)
plot_pacf(t_df, ax=ax[1], method="ols")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 3
#       1 fig, ax = plt.subplots(2, 1)
# ----> 3 plot_acf(t_df)
#       4 plot_pacf(t_df, ax=ax[1], method="ols")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Program Files\Python311\Lib\site-packages\statsmodels\graphics\tsaplots.py:216, in plot_acf(x, ax, lags, alpha, use_vlines, adjusted, fft, missing, title, zero, auto_ylims, bartlett_confint, vlines_kwargs, **kwargs)
#     214 confint = None
#     215 # acf has different return type based on alpha
# --> 216 acf_x = acf(
#     217     x,
#     218     nlags=nlags,
#     219     alpha=alpha,
#     220     fft=fft,
#     221     bartlett_confint=bartlett_confint,
#     222     adjusted=adjusted,
#     223     missing=missing,
#     224 )
#     225 if alpha is not None:
#     226     acf_x, confint = acf_x[:2]
#
# File c:\Program Files\Python311\Lib\site-packages\statsmodels\tsa\stattools.py:674, in acf(x, adjusted, nlags, qstat, fft, alpha, bartlett_confint, missing)
#     670 alpha = float_like(alpha, "alpha", optional=True)
#     671 missing = string_like(
#     672     missing, "missing", options=("none", "raise", "conservative", "drop")
#     673 )
# --> 674 x = array_like(x, "x")
#     675 # TODO: should this shrink for missing="drop" and NaNs in x?
#     676 nobs = x.shape[0]
#
# File c:\Program Files\Python311\Lib\site-packages\statsmodels\tools\validation\validation.py:147, in array_like(obj, name, dtype, ndim, maxdim, shape, order, contiguous, optional)
#     145     if arr.ndim != ndim:
#     146         msg = "{0} is required to have ndim {1} but has ndim {2}"
# --> 147         raise ValueError(msg.format(name, ndim, arr.ndim))
#     148 if shape is not None:
#     149     for actual, req in zip(arr.shape, shape):
#
# ValueError: x is required to have ndim 1 but has ndim 2
