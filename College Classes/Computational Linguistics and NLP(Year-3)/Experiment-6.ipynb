# %% [markdown]
# # Experiment - 6 Word2Vec

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import re

import nltk
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

from gensim.models import Word2Vec

# %% [markdown]
# Importing Data

# %%
df = pd.read_csv('elon_musk_tweets.csv')

tweets = df['text']

tweets
# Out:
# 0       @BillyM2k I find the gold toe sock – inevitabl...
# 1                      Sock Con, the conference for socks
# 2       Always something new for the magazine cover an...
# 3                        @ExplainThisBob This guy gets it
# 4       Sock tech is so advanced that you can get pret...
#                               ...
# 3536    Check out my spicy 🌶️ 🔥 OnlyGANs!! https://t.c...
# 3537                @derek_j_morris @pmarca Major problem
# 3538                                        @EvaFoxU Nice
# 3539    @DavidSacks A Russia-China alliance is inevita...
# 3540                                 @PeterDiamandis Yeah
# Name: text, Length: 3541, dtype: object

# %% [markdown]
# Preprocessing with Porter Stemmer and WordNetLemmatizer

# %%
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

tweetList = []

stopWords = set(stopwords.words('english'))

for tweet in tweets:
    # Convert the tweet to lowercase using REGEX
    for f in re.findall("([A-Z]+)", tweet):
        tweet = tweet.replace(f, f.lower())

    # Removing special characters and replacing them with a space
    tweet = re.sub("[^A-Za-z0-9]", " ", tweet, 0, re.IGNORECASE)
    
    # From a single sentence, store all the words 
    wordsInTweet = nltk.word_tokenize(tweet)
    
    # Filter out all the stop words
    wordsInTweet = [word for word in wordsInTweet if word not in stopWords]
    
    # Stem each of the tweets
    wordsInTweet = [stemmer.stem(word) for word in wordsInTweet if word not in stopWords]
    
    # Lemmatize each of the tweets
    wordsInTweet = [lemmatizer.lemmatize(word) for word in wordsInTweet]
    
    # Append them to a list
    tweetList.append(wordsInTweet)

# %% [markdown]
# Final Tokenized Tweets

# %%
tweetList
# Out:
# [['billym2k',
#   'find',
#   'gold',
#   'toe',
#   'sock',
#   'inevit',
#   'kilter',
#   'amp',
#   'wash',
#   'littl',
#   'troubl',
#   'esthet',
#   'amp',
#   'arguabl',
#   'bit',
#   'corpo'],
#  ['sock', 'con', 'confer', 'sock'],
#  ['alway', 'someth', 'new', 'magazin', 'cover', 'articl', 'practic', 'write'],
#  ['explainthisbob', 'guy', 'get'],
#  ['sock',
#   'tech',
#   'advanc',
#   'get',
#   'pretti',
#   'much',
#   'anyth',
#   'sock',
#   'form',
#   'day'],
#  ['must', 'confess', 'penchant', 'creativ', 'sock'],
#  ['slashdot', 'time'],
#  ['tonyadevitti',
#   'historydefin',
#   'success',
#   'fact',
#   'due',
#   'part',
#   'super',
#   'fun',
#   'parti',
#   'spoke',
#   'wrote',
#   'incred',
#   'well'],
#  ['historydefin',
#   'bleak',
#   'post',
#   'mayb',
#   'gener',
#   'click',
#   'happier',
#   'moment',
#   'histori',
#   'would',
#   'nice'],
#  ['mishaboar', 'boringcompani', 'support', 'doge', 'wherev', 'possibl'],
#  ['moon', 'brought', 'u', 'togeth', '69', 'mar', 'futur'],
#  ['without', 'common', 'goal', 'human', 'fight'],
#  ['ppathol', 'exactli'],
#  ['alexberenson',
#   'twitter',
#   'say',
#   'pressur',
#   'govern',
#   'may',
#   'place',
#   'twitter'],
#  ['human', 'reach', 'mar', 'lifetim'],
#  ['flatul', 'earther'],
#  ['owenspark', 'tesmanian', 'com', 'mayb', 'later', 'year'],
#  ['tesmanian',
#   'com',
#   'zip',
#   'around',
#   'vega',
#   'super',
#   'fast',
#   'tesla',
#   'tunnel'],
#  ['evafoxu',
#   'structur',
#   'pack',
#   'right',
#   'overal',
#   'architectur',
#   'physic',
#   'standpoint',
#   'still',
#   'far',
#   'optim'],
#  ['wholemarsblog',
#   'also',
#   'rugged',
#   'relentless',
#   'salt',
#   'spray',
#   'amp',
#   'extrem',
#   'wind',
#   'amp',
#   'storm',
#   'deep',
#   'ocean',
#   'easi'],
#  ['wholemarsblog',
#   'dual',
#   'high',
#   'perform',
#   'termin',
#   'import',
#   'maintain',
#   'connect',
#   'cho',
#   'http',
#   'co',
#   'tu39wsryma'],
#  ['joshseefri', 'fli', 'electr', 'boat', 'would', 'sickkk'],
#  ['starlink', 'boat', 'http', 'co', 'bquju8ngna'],
#  ['cb',
#   'doge',
#   'bad',
#   'high',
#   'time',
#   'futur',
#   'look',
#   'like',
#   'futur',
#   'goe',
#   'fashion'],
#  ['evafoxu',
#   'billym2k',
#   'tesla',
#   'adri',
#   'pretti',
#   'much',
#   'van',
#   'would',
#   'roof',
#   'height',
#   'could',
#   'stand',
#   'sit',
#   'shade'],
#  ['billym2k',
#   'mayb',
#   'option',
#   'solar',
#   'power',
#   'canopi',
#   'extend',
#   'side',
#   'van',
#   'tripl',
#   'roof',
#   'area'],
#  ['micsolana', 'rmcentush', 'exactli'],
#  ['mayb',
#   'tesla',
#   'make',
#   'highli',
#   'configur',
#   'robovan',
#   'peopl',
#   'amp',
#   'cargo'],
#  ['ppathol',
#   'far',
#   'mani',
#   'peopl',
#   'illus',
#   'earth',
#   'overpopul',
#   'even',
#   'though',
#   'birth',
#   'rate',
#   'trend',
#   'http',
#   'co',
#   '5qmlmyg1cr'],
#  ['hope', 'big', 'famili', 'congrat', 'alreadi'],
#  ['popul', 'mar', 'still', 'zero', 'peopl'],
#  ['mark', 'word', 'sadli', 'true'],
#  ['best',
#   'help',
#   'underpopul',
#   'crisi',
#   'collaps',
#   'birth',
#   'rate',
#   'biggest',
#   'danger',
#   'civil',
#   'face',
#   'far'],
#  ['successmind',
#   'pmarca',
#   'wait',
#   'minut',
#   'doc',
#   'tell',
#   'built',
#   'time',
#   'machin',
#   'delorean',
#   'back',
#   'futur'],
#  ['highli',
#   'recommend',
#   'revolut',
#   'mike',
#   'duncan',
#   'especi',
#   'season',
#   '10',
#   'http',
#   'co',
#   'lojxyl2htu'],
#  ['pmarca',
#   'world',
#   'actual',
#   'vastli',
#   'better',
#   'orwel',
#   'imagin',
#   'also',
#   'vastli',
#   'surveil'],
#  ['ggreenwald', 'troubl'],
#  ['slashdot', 'great'],
#  ['billym2k', 'slashdot', 'inde', 'real', 'question'],
#  ['billym2k', 'great', 'experi', 'tokyo', 'osaka'],
#  ['billym2k',
#   'china',
#   'amp',
#   'japan',
#   'awesom',
#   'train',
#   'took',
#   'bullet',
#   'train',
#   'beij',
#   'xi',
#   'see',
#   'terracotta',
#   'armi'],
#  ['super',
#   'fire',
#   'futur',
#   'product',
#   'develop',
#   'awesom',
#   'tesla',
#   'team',
#   'honor',
#   'work'],
#  ['blkmdl3',
#   'nickcannon',
#   'kid',
#   'worth',
#   'possibl',
#   'plan',
#   'increas',
#   'childcar',
#   'benefit',
#   'compan',
#   'http',
#   'co',
#   'lk82cfoxa5'],
#  ['sm', 'agre', 'need', 'address'],
#  ['liv', 'boere', 'world', 'gone', 'mad'],
#  ['hiromichimizuno', 'terribl', 'news'],
#  ['wholemarsblog',
#   'futur',
#   'war',
#   'drone',
#   'human',
#   'crew',
#   'plane',
#   'tank',
#   'chanc',
#   'one',
#   'except',
#   'http',
#   'co',
#   'vfngwzhe65'],
#  ['greg',
#   'price11',
#   'whoever',
#   'control',
#   'teleprompt',
#   'real',
#   'presid',
#   'http',
#   'co',
#   '1rcqmwle9'],
#  ['scottadamssay',
#   'nickcannon',
#   'know',
#   'littl',
#   'today',
#   'want',
#   'know',
#   'mean',
#   'life',
#   'whatev',
#   'right',
#   'quest',
#   'http',
#   'co',
#   'e5us0ddb6f'],
#  ['scottadamssay',
#   'nickcannon',
#   'spong',
#   'amp',
#   'starfish',
#   'obv',
#   'http',
#   'co',
#   'v7bbz7vstw'],
#  ['scottadamssay',
#   'nickcannon',
#   'conscious',
#   'understand',
#   'natur',
#   'univers',
#   'clam',
#   'much'],
#  ['andst7', 'interest', 'behind', 'bot', 'attack'],
#  ['improv',
#   'qualiti',
#   'sleep',
#   'rais',
#   'head',
#   'bed',
#   '3',
#   '5cm',
#   'eat',
#   '3',
#   'hour',
#   'bedtim'],
#  ['polar',
#   'launch',
#   'enabl',
#   'complet',
#   'coverag',
#   'earth',
#   'approv',
#   'local',
#   'govern',
#   'http',
#   'co',
#   '0sshobwdp3'],
#  ['chuckmat'],
#  ['ppathol', 'hello', 'secgov'],
#  ['cb', 'doge', 'fifth', 'element', 'great'],
#  ['erdayastronaut',
#   'ppathol',
#   'planet4589',
#   'nasaspaceflight',
#   'base',
#   'vehicl',
#   'seem',
#   'ok',
#   'flashlight',
#   'http',
#   'co',
#   'nl60xqalqx'],
#  ['spacetelescop', 'cool', 'congrat', 'simul', 'spend', 'money', 'render'],
#  ['chrisdungeon',
#   'alexkehr',
#   'billym2k',
#   'levi',
#   'reread',
#   'life',
#   'greec',
#   'durant',
#   'recent',
#   'month',
#   'read',
#   'american',
#   'ca',
#   'http',
#   'co',
#   'vdpplbpfmz'],
#  ['alexkehr', 'billym2k', 'levi', 'recommend', 'lot', 'book'],
#  ['levi', 'mani', 'littl', 'red', 'green', 'led', 'indic'],
#  ['billym2k',
#   'levi',
#   'youtub',
#   'keep',
#   'play',
#   'annoy',
#   'scam',
#   'ad',
#   'everi',
#   'time',
#   'use',
#   'algorithm',
#   'convinc',
#   'http',
#   'co',
#   '1w3phqioln'],
#  ['ppathol',
#   'planet4589',
#   'nasaspaceflight',
#   'one',
#   'thing',
#   'go',
#   'forward',
#   'particular',
#   'http',
#   'co',
#   'zqqnolhcdn'],
#  ['adamirvinmus',
#   'breitbartnew',
#   'trump',
#   'would',
#   '82',
#   'end',
#   'term',
#   'old',
#   'chief',
#   'execut',
#   'anyth',
#   'http',
#   'co',
#   'mxfqqdmk7g'],
#  ['joetalkshow',
#   'breitbartnew',
#   'yeah',
#   'much',
#   'drama',
#   'realli',
#   'want',
#   'bull',
#   'china',
#   'shop',
#   'situat',
#   'everi',
#   'sing',
#   'http',
#   'co',
#   'jnuteddwqx'],
#  ['breitbartnew',
#   'hate',
#   'man',
#   'time',
#   'trump',
#   'hang',
#   'hat',
#   'amp',
#   'sail',
#   'sunset',
#   'dem',
#   'shoul',
#   'http',
#   'co',
#   'sn4gdltiw9'],
#  ['tesla',
#   'automat',
#   'cabin',
#   'overheat',
#   'protect',
#   'make',
#   'real',
#   'differ',
#   'record',
#   'heatwav',
#   'abil',
#   'adjust',
#   'http',
#   'co',
#   '0u1n37g2al'],
#  ['bonginoreport', 'true'],
#  ['planet4589',
#   'nasaspaceflight',
#   'cryogen',
#   'fuel',
#   'ad',
#   'challeng',
#   'evapor',
#   'creat',
#   'fuel',
#   'air',
#   'explos',
#   'ri',
#   'http',
#   'co',
#   '59ujajy5sj'],
#  ['nasaspaceflight', 'yeah', 'actual', 'good', 'team', 'ass', 'damag'],
#  ['billym2k', 'mimic', 'dark', 'moon', 'star', 'ruin'],
#  ['wholemarsblog', 'absolut'],
#  ['mrbeast',
#   'good',
#   'chanc',
#   'experienc',
#   'least',
#   'mild',
#   'acid',
#   'reflux',
#   'night',
#   'affect',
#   'qualiti',
#   'sleep',
#   'without',
#   'conscious',
#   'awar'],
#  ['gailalfaratx',
#   'tesla',
#   'teslacn',
#   'teslaownersebay',
#   'blueskykit',
#   'kristennetten',
#   'jennicurr',
#   'daelmor',
#   'ihearttesla',
#   'http',
#   'co',
#   'i8l3sthvci'],
#  ['cb', 'doge', 'ancient', 'time'],
#  ['booster',
#   'propuls',
#   'section',
#   'damag',
#   'appear',
#   'minor',
#   'need',
#   'inspect',
#   'engin',
#   'http',
#   'co',
#   'y4rbnuj5r'],
#  ['starship', 'launch', 'site', 'tonight', 'http', 'co', 'len70rgcnf'],
#  ['teslarati', 'residentspong', 'join', 'underground', 'movement'],
#  ['excit', 'nasawebb', 'potenti'],
#  ['oh', 'ironi', 'lol'],
#  ['ajtourvil',
#   'tesla',
#   'problem',
#   'recycl',
#   '4680',
#   'pack',
#   'think',
#   'batteri',
#   'pack',
#   'super',
#   'high',
#   'grade',
#   'ore',
#   'http',
#   'co',
#   'uabjd6nbn'],
#  ['erdayastronaut',
#   'spacex',
#   'caspar',
#   'stanley',
#   'izanramos2002',
#   'importantli',
#   'need',
#   'delet',
#   'thermal',
#   'protect',
#   'rem',
#   'http',
#   'co',
#   'b25wniwbpo'],
#  ['arctechinc',
#   '10',
#   '13',
#   'goe',
#   'intern',
#   'beta',
#   'tomorrow',
#   'extern',
#   'next',
#   'week',
#   'handl',
#   'chuck',
#   'complex',
#   'left',
#   'turn',
#   'bet',
#   'http',
#   'co',
#   '7ncsj5udf9'],
#  ['karpathi', 'thank', 'everyth', 'done', 'tesla', 'honor', 'work'],
#  ['davidsack', 'absolut', 'lithium', 'batteri', 'new', 'oil'],
#  ['sirineati', 'test', 'goe', 'well', 'soon', 'next', 'month'],
#  ['sawyermerritt', 'cool'],
#  ['give', 'whole', 'new', 'mean', 'go', 'pro'],
#  ['sruhl', 'imagin', 'msnbc'],
#  ['cinematographi', 'http', 'co', 'angjqkbq5w'],
#  ['tim',
#   'ottawa',
#   'teslaownerssv',
#   'mar',
#   'admittedli',
#   'fixer',
#   'upper',
#   'planet'],
#  ['teslaownerssv', 'scale', 'amp', 'anyon', 'visit'],
#  ['waitbutwhi',
#   'wonder',
#   'speci',
#   'magellan',
#   'cloud',
#   'wonder',
#   'live',
#   'big',
#   'galaxi',
#   'orbit'],
#  ['ppathol',
#   'erdayastronaut',
#   'spacex',
#   'caspar',
#   'stanley',
#   'izanramos2002',
#   'small',
#   'tube',
#   'amp',
#   'wire',
#   'need',
#   'nest',
#   'b',
#   'http',
#   'co',
#   'fphpnsxski'],
#  ['djsnm',
#   'erdayastronaut',
#   'spacex',
#   'caspar',
#   'stanley',
#   'izanramos2002',
#   'electr',
#   'power',
#   'booster',
#   'amp',
#   'ship',
#   'need',
#   'even',
#   'http',
#   'co',
#   'hiywc7jx56'],
#  ['erdayastronaut',
#   'spacex',
#   'caspar',
#   'stanley',
#   'izanramos2002',
#   'enabl',
#   'engin',
#   'take',
#   'heat',
#   'without',
#   'shroud',
#   'might',
#   'save',
#   'http',
#   'co',
#   '5h34xxlmvv'],
#  ['erdayastronaut',
#   'spacex',
#   'caspar',
#   'stanley',
#   'izanramos2002',
#   'mass',
#   'necessit',
#   'engin',
#   'design',
#   'count',
#   'en',
#   'http',
#   'co',
#   'yaeengsntm'],
#  ['dragon', 'launch', '2', 'min', 'http', 'co', 'dbqdcbby6b'],
#  ['nasaearth', 'global'],
#  ['sciguyspac', 'cumul', 'tonnag', 'orbit', 'year', 'right', 'metric'],
#  ['akidesir', 'sawyermerritt', 'write', 'fcc', 'would', 'great'],
#  ['sawyermerritt',
#   'charli',
#   'ergen',
#   'tri',
#   'steal',
#   '12ghz',
#   'band',
#   'meant',
#   'space',
#   'internet',
#   'cool'],
#  ['cleantechnica', 'progress'],
#  ['teslaownerssv',
#   'tesla',
#   'make',
#   'progress',
#   'steam',
#   'integr',
#   'demo',
#   'probabl',
#   'next',
#   'month'],
#  ['teslaownerssv', 'cb', 'doge', 'flat', 'trade'],
#  ['cb',
#   'doge',
#   'actual',
#   'true',
#   'suggest',
#   'team',
#   'need',
#   'quit',
#   'pointi',
#   'sinc',
#   'b',
#   'http',
#   'co',
#   'fyufn8tnmm'],
#  ['billym2k', 'cryptowhal', 'bagel'],
#  ['hohocho', 'inflat', 'calm', 'lower', 'price', 'car'],
#  ['tesla', 'protect', 'life', 'earth', 'spacex', 'extend', 'life', 'beyond'],
#  ['ppathol',
#   '20',
#   '30',
#   'year',
#   'first',
#   'human',
#   'land',
#   'launch',
#   'rate',
#   'growth',
#   'exponenti',
#   'assum',
#   'transfer',
#   '100k',
#   'http',
#   'co',
#   'iryr7iq09h'],
#  ['mar', 'may', 'fixer', 'upper', 'planet', 'great', 'potenti'],
#  ['karpathi', 'also', 'worth', 'get', 'particl', 'counter'],
#  ['owenspark',
#   'karpathi',
#   'futur',
#   'product',
#   'list',
#   'especi',
#   'import',
#   'place',
#   'like',
#   'austin',
#   'next',
#   'http',
#   'co',
#   'aqbfmshdgn'],
#  ['konstructivizm', 'thing', 'get', 'wild', 'andromeda', 'collid', 'galaxi'],
#  ['energyb', 'liv', 'boere', 'keep', 'run'],
#  ['karpathi',
#   'true',
#   'co2',
#   'monitor',
#   'desk',
#   'beep',
#   'whenev',
#   'ppm',
#   'gt',
#   '1000'],
#  ['spacex',
#   'space',
#   'station',
#   'twice',
#   'much',
#   'use',
#   'mass',
#   'orbit',
#   'rest',
#   'earth',
#   'combin'],
#  ['tanayj', 'absolut'],
#  ['erdayastronaut',
#   'leveakin',
#   'accur',
#   'word',
#   'propel',
#   'rather',
#   'fuel',
#   'starship',
#   '78',
#   'liquid',
#   'oxygen',
#   'http',
#   'co',
#   'nma1yyvtu2'],
#  ['rainmaker1973', 'use', 'exampl', 'lot'],
#  ['tj',
#   'cooney',
#   'spacex',
#   'starlink',
#   'bandwidth',
#   'vari',
#   'lot',
#   'depend',
#   'user',
#   'termin',
#   'densiti',
#   'amp',
#   'time',
#   'day',
#   'th',
#   'http',
#   'co',
#   'qfsjgifsay'],
#  ['tj', 'cooney', 'spacex', 'starlink', 'gamechang', 'remot', 'locat'],
#  ['one', 'best', 'featur', 'model', 'x', 'http', 'co', 'zutcsd7fiz'],
#  ['johnnacrider1', 'potu', 'tesla', 'made', 'usa', 'vehicl'],
#  ['childrenshd', 'total', 'scam'],
#  ['mn', 'googl', 'calv', 'bigger', 'tho'],
#  ['think',
#   'fremont',
#   'derelict',
#   'build',
#   'amp',
#   'giga',
#   'nevada',
#   'rock',
#   'amp',
#   'bush',
#   'start',
#   'california',
#   'http',
#   'co',
#   'vzuuuva1xz'],
#  ['congrat',
#   'tesla',
#   'fremont',
#   'giga',
#   'nevada',
#   'make',
#   '2',
#   'millionth',
#   'car'],
#  ['plea', 'vote', 'share', 'tesla', 'http', 'co', 'zbfwv0pkgg'],
#  ['wholemarsblog', 'yeah'],
#  ['sawyermerritt',
#   'spacex',
#   'start',
#   '1000',
#   'time',
#   'mass',
#   'orbit',
#   'per',
#   'year',
#   'need',
#   'make',
#   'life',
#   'multiplanetari'],
#  ['billym2k', 'alreadi'],
#  ['teslaconom',
#   'haha',
#   'damn',
#   'mayb',
#   'take',
#   'shirt',
#   'often',
#   'free',
#   'nip',
#   'alreadi',
#   'back',
#   'factori',
#   'btw'],
#  ['teslaownerssv', 'still', 'need', 'tweak'],
#  ['renatakonkoli', 'engin', 'feed', 'classic'],
#  ['engin', 'feed', 'rememb', '70', 'mean', 'definit', 'spring', 'chicken'],
#  ['billym2k',
#   'arguabl',
#   'know',
#   'noth',
#   'death',
#   'amp',
#   'tax',
#   'certainti',
#   'bf'],
#  ['waitbutwhi', 'undertheraedar', 'earth', 'basic', 'empti', 'human'],
#  ['realmeetkevin', 'exactli'],
#  ['wholemarsblog',
#   'tbh',
#   'good',
#   'motiv',
#   'work',
#   'eat',
#   'healthier',
#   'amp',
#   'mayb',
#   'take',
#   'shirt',
#   'outsid',
#   'year',
#   'haha'],
#  ['jonerlichman', '16', 'year', 'ago'],
#  ['dogecoin', 'upgrad'],
#  ['eff', 'sound', 'bad'],
#  ['reuter',
#   'real',
#   'life',
#   'fantasi',
#   'caught',
#   'landsid',
#   'escap',
#   'realiti'],
#  ['optimu', 'prime', 'http', 'co', 'dmipaiyevn'],
#  ['alifarhat79',
#   'wapodavenport',
#   'walterisaacson',
#   'jeff',
#   'foust',
#   'rubber',
#   'glue'],
#  ['wapodavenport',
#   'walterisaacson',
#   'jeff',
#   'foust',
#   'interest',
#   'smart',
#   'move',
#   'china',
#   'expend',
#   'rocket',
#   'futur'],
#  ['jgebbia',
#   'airbnb',
#   'bcheski',
#   'nathanblec',
#   'congrat',
#   'incred',
#   'compani',
#   'airbnb',
#   'book',
#   '2'],
#  ['heydave7', 'tesla', 'true'],
#  ['dolllarpo',
#   'servic',
#   'turn',
#   'next',
#   'month',
#   'time',
#   'requir',
#   'deliv',
#   'user',
#   'termin',
#   'order',
#   'http',
#   'co',
#   'q1vvqv58ak'],
#  ['excit',
#   'work',
#   'tesla',
#   'servic',
#   'enabl',
#   'hour',
#   'servic',
#   'often',
#   'possibl',
#   'appli',
#   'formula',
#   '1',
#   'pit',
#   'crew',
#   'techniqu',
#   'tesla'],
#  ['rainmaker1973',
#   'major',
#   'volcan',
#   'erupt',
#   'underappreci',
#   'civiliz',
#   'risk'],
#  ['rainmaker1973', 'tough', 'time'],
#  ['starlink', 'avail', '36', 'countri', 'http', 'co', 'nh1zpfd2om'],
#  ['congrat',
#   'spacex',
#   'team',
#   'record',
#   'number',
#   'launch',
#   'http',
#   'co',
#   'nb8ozrbqz5'],
#  ['wintonark',
#   'self',
#   'drive',
#   'electr',
#   'car',
#   'matter',
#   'ga',
#   'car',
#   'without',
#   'autonomi',
#   'like',
#   'ride',
#   'ho',
#   'http',
#   'co',
#   '8l7oyfmdyz'],
#  ['wholemarsblog', 'softwar', 'key', 'futur'],
#  ['spacex', 'falcon', 'rise', 'fog'],
#  ['spacex', 'falcon', 'moon'],
#  ['sjm', 'http', 'co', 't6xaimyz9m'],
#  ['armand', 'gman', 'great', 'thread'],
#  ['nichegam', 'cb', 'doge', 'deep', 'histori', 'meme', 'rock'],
#  ['teslaownerssv',
#   'icannot',
#   'enough',
#   'ajtourvil',
#   'major',
#   'improv',
#   'respect',
#   'complex',
#   'left',
#   'turn'],
#  ['teslaownerssv',
#   'icannot',
#   'enough',
#   'ajtourvil',
#   'mayb',
#   'end',
#   'week',
#   'team',
#   'work',
#   'hard'],
#  ['icannot', 'enough', 'ajtourvil', 'inde'],
#  ['amount',
#   'attent',
#   'gone',
#   'supernova',
#   'super',
#   'suck',
#   'unfortun',
#   'even',
#   'trivial',
#   'articl',
#   'http',
#   'co',
#   'xcwdqms4az'],
#  ['ppathol',
#   'michaelsiconolf',
#   'kirstengrind',
#   'emilyglaz',
#   'mostli',
#   'medium',
#   'click',
#   'maxim',
#   'machin',
#   'http',
#   'co',
#   'odiszab44w'],
#  ['tesla', 'come', 'free', 'karaok', 'app', 'http', 'co', 'mza3wmhypl'],
#  ['da', 'babi', 'would', 'hit'],
#  ['jhall',
#   'medium',
#   'click',
#   'seek',
#   'machin',
#   'dress',
#   'truth',
#   'seek',
#   'machin'],
#  ['michaelsiconolf', 'kirstengrind', 'emilyglaz', 'http', 'co', 'ioq3egoqj3'],
#  ['dvorahfr',
#   'chicago',
#   'glenn',
#   'sawyermerritt',
#   'michaelsiconolf',
#   'sure',
#   'seem',
#   'way'],
#  ['sawyermerritt',
#   'real',
#   'problem',
#   'michaelsiconolf',
#   'zero',
#   'journalist',
#   'integr'],
#  ['sawyermerritt', 'pictur', 'worth', '1000', 'tweet'],
#  ['sawyermerritt', 'yeah', 'sergey', 'yesterday', 'afternoon'],
#  ['singl',
#   'piec',
#   'cast',
#   'reduc',
#   'weight',
#   'greatli',
#   'simplifi',
#   'factori',
#   'increas',
#   'ride',
#   'qualiti',
#   'amp',
#   'reduc',
#   'road',
#   'nois',
#   'http',
#   'co',
#   'hjw4klpfdg'],
#  ['gailalfaratx',
#   'teslasolar',
#   'tesla',
#   'douglewinenergi',
#   'dimazeniuk',
#   'evafoxu',
#   'dirtytesla',
#   'wholemarsblog',
#   'kristennetten',
#   'brosfordecarb',
#   'good',
#   'articl'],
#  ['video', 'game', 'enjoy', 'past', 'year', 'two'],
#  ['60minut', 'evid', 'simul'],
#  ['movi',
#   'idea',
#   'bos',
#   'babi',
#   'meet',
#   'da',
#   'boot',
#   'da',
#   'babi',
#   'hijink',
#   'high',
#   'sea'],
#  ['icannot', 'enough', 'wholemarsblog', 'lmaooo', 'absolut'],
#  ['lovemesomemusk', 'wholemarsblog', 'nope'],
#  ['teslaownerssv',
#   'heydave7',
#   'wholemarsblog',
#   'wsj',
#   'call',
#   'guess',
#   'wsj',
#   'suppos',
#   'high',
#   'standard',
#   'http',
#   'co',
#   'dge4locud7'],
#  ['heydave7',
#   'wholemarsblog',
#   'wsj',
#   'wsj',
#   'run',
#   'mani',
#   'b',
#   'hit',
#   'piec',
#   'tesla',
#   'lost',
#   'count',
#   'embarrass',
#   'http',
#   'co',
#   'dr557glztn'],
#  ['wholemarsblog', 'even', 'sex', 'age', 'sigh'],
#  ['teslahyp',
#   'wholemarsblog',
#   'yeah',
#   'charact',
#   'assassin',
#   'attack',
#   'reach',
#   'new',
#   'level',
#   'year',
#   'art',
#   'http',
#   'co',
#   'behggaqaku'],
#  ['wholemarsblog',
#   'total',
#   'b',
#   'sergey',
#   'friend',
#   'parti',
#   'togeth',
#   'last',
#   'night',
#   'seen',
#   'http',
#   'co',
#   'yq57ocjtuf'],
#  ['iron',
#   'disney',
#   'would',
#   'disparag',
#   'entir',
#   'class',
#   'rodent',
#   'main',
#   'charact',
#   'rodent',
#   'jealou',
#   'mayb'],
#  ['dark',
#   'origin',
#   'lem',
#   'mass',
#   'suicid',
#   'myth',
#   'http',
#   'co',
#   'wn7vg2mujr'],
#  ['jeffskol', 'thank', 'jeff'],
#  ['michaelsiconolf',
#   'kirstengrind',
#   'emilyglaz',
#   'sickonolfi',
#   'pack',
#   'attack',
#   'chihuahua',
#   'burn',
#   'phone',
#   'line',
#   'today',
#   'http',
#   'co',
#   'kowp9nq1p'],
#  ['marceloplima', 'exactli'],
#  ['sawyermerritt', 'heydave7', 'wholemarsblog', 'wsj', 'good', 'point'],
#  ['nasaspaceflight',
#   'sub',
#   'lightspe',
#   'need',
#   'interstellar',
#   'intergalact',
#   'tough'],
#  ['medium', 'click', 'seek', 'machin', 'dress', 'truth', 'seek', 'machin'],
#  ['compat',
#   'exist',
#   'religion',
#   'sure',
#   'god',
#   'would',
#   'want',
#   'u',
#   'see',
#   'creation'],
#  ['new',
#   'philosophi',
#   'futur',
#   'need',
#   'believ',
#   'curio',
#   'univers',
#   'expand',
#   'human',
#   'http',
#   'co',
#   'xzidyna6uc'],
#  ['sama', 'new', 'philosophi', 'futur', 'need'],
#  ['heydave7',
#   'wsj',
#   'michaelsiconolf',
#   'moreov',
#   'talk',
#   'sergey',
#   'yesterday',
#   'say',
#   'neither',
#   'anyon',
#   'know',
#   'talk',
#   'wsj'],
#  ['heydave7',
#   'wsj',
#   'public',
#   'person',
#   'standard',
#   'win',
#   'defam',
#   'lawsuit',
#   'news',
#   'org',
#   'almost',
#   'imposs',
#   'http',
#   'co',
#   'qkyd2hlml7'],
#  ['teslaownerssv', 'ppathol', 'serious'],
#  ['ppathol', 'busi', 'insid', 'trade', 'real', 'public'],
#  ['gailalfaratx',
#   'chicago',
#   'glenn',
#   'michaelsiconolf',
#   'kirstengrind',
#   'emilyglaz',
#   'yeah',
#   '8000',
#   'year',
#   'ago'],
#  ['ppathol', 'michaelsiconolf', 'kirstengrind', 'emilyglaz', 'would', 'nice'],
#  ['trungtphan',
#   'chicago',
#   'glenn',
#   'michaelsiconolf',
#   'kirstengrind',
#   'emilyglaz',
#   'exactli'],
#  ['chicago',
#   'glenn',
#   'michaelsiconolf',
#   'kirstengrind',
#   'emilyglaz',
#   'weirdli',
#   'public',
#   'still',
#   'print',
#   'million',
#   'paper',
#   'copi',
#   'everi',
#   'day'],
#  ['chicago',
#   'glenn',
#   'michaelsiconolf',
#   'kirstengrind',
#   'emilyglaz',
#   '99',
#   'journal',
#   'read',
#   'someon',
#   'el',
#   'stori',
#   'http',
#   'co',
#   'i7ecporwf'],
#  ['michaelsiconolf',
#   'kirstengrind',
#   'emilyglaz',
#   'sickonolfi',
#   'zero',
#   'journalist',
#   'integr',
#   'http',
#   'co',
#   'gojdqeomwj'],
#  ['much', 'harder', 'make', 'friend', 'enemi', 'skill', 'latter', 'improv'],
#  ['dirtytesla', 'work', 'super', 'hard', '10', '13', 'readi', 'yet'],
#  ['micsolana', 'wikipedia', 'lose', 'object', 'jimmi', 'wale'],
#  ['say', 'sure', 'starship', 'reach', 'escap', 'veloc', 'hubri', 'certainli'],
#  ['chicago', 'glenn', 'thank', 'farmer'],
#  ['wholemarsblog', 'product', 'bring', 'joy', 'rare'],
#  ['teslaownerssv', 'earli', 'say', 'sure'],
#  ['snjejxjbbdbebjx', 'would', 'unwis', 'risk'],
#  ['tesla', 'commod', 'price', 'trend', 'fwiw'],
#  ['inflat', 'might', 'trend'],
#  ['futurejurvetson', 'tesla', 'gjurvetson', 'thank', 'support', 'year'],
#  ['cb', 'doge', 'lexfridman', 'explainthisbob', 'sigh'],
#  ['race', 'set', 'harley', 'quinn', 'http', 'co', '79xaboxakk'],
#  ['stockmktnewz', 'live', 'interest', 'time'],
#  ['peopl', 'nonsens', 'person', 'like', 'littl', 'nonsens'],
#  ['interact',
#   'almost',
#   'twitter',
#   'account',
#   'seem',
#   'much',
#   'lower',
#   'recent',
#   'week',
#   'amp',
#   'day',
#   'accur'],
#  ['saxon', 'http', 'co', 'uth4uqieyp'],
#  ['spideycyp', '155', 'base'],
#  ['friend', 'made', '2', 'year', 'ago', 'http', 'co', 'xzlmpmpnt7'],
#  ['tri', 'voic', 'command', 'open', 'butthol', 'tesla'],
#  ['historyinp', 'great', 'style'],
#  ['teslapodcast',
#   'senatedem',
#   'sen',
#   'joemanchin',
#   'senatorsinema',
#   'senategop',
#   'good',
#   'point',
#   'time',
#   'move',
#   'hybrid',
#   'car',
#   'phase'],
#  ['icannot',
#   'enough',
#   'dirtytesla',
#   '10',
#   '13',
#   'probabl',
#   'week',
#   'away',
#   'ye',
#   'peopl',
#   'outsid',
#   'california',
#   'notic',
#   'improv'],
#  ['realiti', 'actual', 'alien', 'soap', 'opera', 'rate', 'would'],
#  ['mayb', 'free', 'peopl', 'jail', 'weed', 'http', 'co', 'ayo0zc79lz'],
#  ['ajtourvil', 'spacex', 'good', 'thread'],
#  ['still', 'time', 'vote', 'http', 'co', 'zbfwv0pkgg'],
#  ['x', 'doge'],
#  ['spideycyp', '155', 'much', 'water', 'bridg', 'sinc'],
#  ['teslaownerssv', 'yeah'],
#  ['teslaownerssv', 'billym2k', 'wholemarsblog', 'mayb', 'twitter', 'becom'],
#  ['teslaownerssv',
#   'billym2k',
#   'wholemarsblog',
#   'sure',
#   'hard',
#   'find',
#   'news',
#   'sourc',
#   'accur',
#   'relev',
#   'amp',
#   'total',
#   'http',
#   'co',
#   'wdcup9ocob'],
#  ['cb', 'doge', 'floki', 'pic', 'tomorrow'],
#  ['billym2k',
#   'wholemarsblog',
#   'medium',
#   'strong',
#   'neg',
#   'bia',
#   'amp',
#   'driven',
#   'click',
#   'help',
#   'unfortuna',
#   'http',
#   'co',
#   'l7ole5l6v'],
#  ['thanksgiv',
#   'last',
#   'year',
#   'watch',
#   'one',
#   'mani',
#   'episod',
#   'vike',
#   'http',
#   'co',
#   'ra7lijkrhd'],
#  ['came',
#   'across',
#   'pretti',
#   'good',
#   'cnbc',
#   'piec',
#   'spacex',
#   'amp',
#   'starship',
#   'http',
#   'co',
#   'relyzc40m9'],
#  ['ppathol', 'estim', 'seem', 'high', 'point', 'valid'],
#  ['worth', 'read', 'close', 'match', 'philosophi', 'http', 'co', 'cwem6qbobi'],
#  ['teslarati', 'yahoofin', 'petebuttigieg', 'tesla', 'johnnacrider1', 'cool'],
#  ['ratio', 'digit', 'biolog', 'comput', 'grow', 'fast', 'worth', 'track'],
#  ['sirineati', 'success', 'orbit', 'flight', 'probabl', '1', '12', 'month'],
#  ['garyblack00', 'kid', 'q2', 'made', 'car'],
#  ['dogeofficialceo',
#   'chicago',
#   'glenn',
#   'mysa',
#   'happydad',
#   'stone',
#   'destini'],
#  ['john', 'fullsendpodcast', 'fun', 'hang'],
#  ['dogeofficialceo', 'chicago', 'glenn', 'mysa', 'happydad', 'whiskey'],
#  ['chicago',
#   'glenn',
#   'mysa',
#   'happydad',
#   'yeah',
#   'pretti',
#   'good',
#   'like',
#   'name'],
#  ['mysa',
#   'true',
#   'tesla',
#   '5',
#   'min',
#   'austin',
#   'intern',
#   'airport',
#   'would',
#   'silli',
#   'build',
#   'anoth',
#   'privat',
#   'airport',
#   'http',
#   'co',
#   'fw7u9osepz'],
#  ['hustl',
#   'get',
#   'starship',
#   'booster',
#   '7',
#   'back',
#   'pad',
#   'test',
#   'outer',
#   'ring',
#   '20',
#   'engin'],
#  ['full', 'send', 'podcast', 'http', 'co', '01fmxyrrvr'],
#  ['thank', 'good', 'senat', 'manchin'],
#  ['le', '5', 'twitter', 'daili', 'user', 'fake', 'spam'],
#  ['andst7',
#   'herebi',
#   'challeng',
#   'paraga',
#   'public',
#   'debat',
#   'twitter',
#   'bot',
#   'percentag',
#   'let',
#   'prove',
#   'publ',
#   'http',
#   'co',
#   'gv5bbgivuq'],
#  ['evafoxu', 'ppathol', 'andst7', 'seem'],
#  ['ppathol', 'andst7', 'good', 'question'],
#  ['cb', 'doge', 'somehow', '54', 'follow'],
#  ['andst7',
#   'good',
#   'summari',
#   'problem',
#   'twitter',
#   'simpli',
#   'provid',
#   'method',
#   'sampl',
#   '100',
#   'account',
#   'http',
#   'co',
#   'lanla7n2yr'],
#  ['love', 'smell', 'hydraul', 'fluid', 'morn'],
#  ['launch', 'pad', 'http', 'co', 'qfvpvkla9v'],
#  ['move', 'rocket', 'launch', 'pad', 'http', 'co', 'npvq1tyloy'],
#  ['twitter', 'spoken'],
#  ['fsd', 'beta', '10', '69', 'drop', '8', '20'],
#  ['truth', 'tesla', 'brettlindquist', 'garyblack00', 'yeah', 'cool'],
#  ['saxon', 'jame', 'musk', 'http', 'co', 'd7fkw4iqiu'],
#  ['garyblack00',
#   'martinviecha',
#   'grow',
#   '50',
#   'year',
#   'requir',
#   'insan',
#   'amount',
#   'work',
#   'achiev',
#   'outstand',
#   'execut'],
#  ['sayssimonson', 'mayb', 'invest', 'autom'],
#  ['sayssimonson', 'seem', 'high'],
#  ['releas', 'big'],
#  ['ppathol', 'true'],
#  ['quit', 'day', 'http', 'co', 'uyqzwcvgk7'],
#  ['sawyermerritt',
#   'ye',
#   'hope',
#   'unlik',
#   'event',
#   'twitter',
#   'forc',
#   'deal',
#   'close',
#   'equiti',
#   'pa',
#   'http',
#   'co',
#   'wse0ew6bmp'],
#  ['wholemarsblog', 'tesla', 'fremont', 'team', 'kick'],
#  ['sciguyspac', 'brycespacetech', 'spacex', 'falcon', 'team'],
#  ['evasteslasplaid', 'happen', 'almost', 'everyon'],
#  ['8', 'year', 'ago', 'http', 'co', 'hpk5r5ums6'],
#  ['jason',
#   'come',
#   'soon',
#   'part',
#   '3',
#   'scale',
#   'sustain',
#   'energi',
#   'civiliz',
#   'level',
#   'enabl',
#   'bright',
#   'futur',
#   'earth'],
#  ['tesla',
#   '500',
#   'mile',
#   'rang',
#   'semi',
#   'truck',
#   'start',
#   'ship',
#   'year',
#   'cybertruck',
#   'next',
#   'year'],
#  ['wrote', '6', 'year', 'ago', 'http', 'co', 'r9gdxpctzu'],
#  ['attempt', 'long', 'durat', 'engin', 'fire', 'test', 'autogen', 'pressur'],
#  ['starship', 'b7', 'static', 'fire', 'http', 'co', 'tabpsd9lsv'],
#  ['sourpatchlyd',
#   'true',
#   'alreadi',
#   'get',
#   'audit',
#   'everi',
#   'year',
#   'default'],
#  ['wholemarsblog',
#   'think',
#   'approv',
#   'languag',
#   'day',
#   'height',
#   'challeng',
#   'seller'],
#  ['deep', 'thot', 'http', 'co', '0ecpd30qa'],
#  ['tesla247', 'thank', 'alreadi', 'one'],
#  ['ppathol', 'guardian', 'tesla', 'advertis', 'car', 'compani'],
#  ['evafoxu',
#   'wisitlik',
#   'wholemarsblog',
#   'kristennetten',
#   '99brownkaryl',
#   'driveteslaca',
#   'real',
#   'scam',
#   'dowd'],
#  ['guardian',
#   'guardian',
#   'swallow',
#   'scam',
#   'video',
#   'hook',
#   'line',
#   'amp',
#   'sinker',
#   'http',
#   'co',
#   'd64opwlvfg'],
#  ['cb', 'doge', 'coincid'],
#  ['sticki', 'situat'],
#  ['uberfact',
#   'good',
#   'run',
#   'human',
#   'long',
#   'way',
#   'go',
#   'equal',
#   'time',
#   'earth'],
#  ['mar', 'one', 'day', 'http', 'co', 'nf4hml8dkx'],
#  ['u', 'seen', 'sex', 'tape', 'http', 'co', 'acbqirz4sh'],
#  ['ahem', 'twitter', 'http', 'co', 'lcdpoeiei5'],
#  ['techau',
#   'wintonark',
#   'would',
#   'pretti',
#   'wild',
#   'car',
#   'compani',
#   'made',
#   'power',
#   'supercomput',
#   'earth'],
#  ['techau',
#   'wintonark',
#   'phase',
#   'dojo',
#   'need',
#   'buy',
#   'mani',
#   'increment',
#   'gpu',
#   'next',
#   'year'],
#  ['wholemarsblog',
#   'wintonark',
#   'waitlist',
#   'long',
#   'enabl',
#   'ramp',
#   'product'],
#  ['ad', '13', 'inner', 'engin', 'http', 'co', 'ooofegl0hr'],
#  ['wintonark', 'yike'],
#  ['anoth', 'orbit', 'plane', 'polar', 'satellit', 'http', 'co', 'udl6wstlut'],
#  ['billfoxla', 'strang', 'receiv', 'littl', 'attent', 'medium'],
#  ['billfoxla', '400k', 'one', 'border', 'cross', 'le', 'year'],
#  ['congrat',
#   'giga',
#   'shanghai',
#   'make',
#   'millionth',
#   'car',
#   'total',
#   'tesla',
#   'made',
#   '3m',
#   'http',
#   'co',
#   '2aee6slcuv'],
#  ['teslaownerssv',
#   'drive',
#   'autonomi',
#   'thescottpaint',
#   'product',
#   'much',
#   'bigger',
#   'challeng',
#   'demand'],
#  ['teslaownerssv', 'hope', 'self', 'sustain', 'citi', 'mar', '20', 'year'],
#  ['read', 'instruct', 'http', 'co', 'bwyzsee0q8'],
#  ['teslaownerssv',
#   'ye',
#   'tesla',
#   'autopilot',
#   'ai',
#   'team',
#   'amaz',
#   'work',
#   '10',
#   '69',
#   'worth',
#   'name'],
#  ['wonderofsci', 'mercuri', 'forbidden', 'candi'],
#  ['elon',
#   'quot',
#   'almost',
#   'earth',
#   'energi',
#   'come',
#   'sun',
#   'alreadi',
#   'would',
#   'dark',
#   'icebal',
#   'near',
#   'absolut',
#   'http',
#   'co',
#   'qh8gr7w0sq'],
#  ['teslaownerssv',
#   'although',
#   'team',
#   'would',
#   'man',
#   'u',
#   'fav',
#   'team',
#   'kid'],
#  ['standup', 'side', 'hustl'],
#  ['teslaownerssv',
#   'buy',
#   'coca',
#   'cola',
#   'put',
#   'cocain',
#   'back',
#   'despit',
#   'extrem',
#   'popular',
#   'move'],
#  ['teslaownerssv', 'long', 'run', 'joke', 'twitter', 'buy', 'sport', 'team'],
#  ['wholemarsblog', 'karpathi', 'got', 'build', 'youtub', 'subscript'],
#  ['evafoxu',
#   'note',
#   'tri',
#   'reduc',
#   'deliveri',
#   'time',
#   'quickli',
#   'possibl',
#   'long',
#   'wait',
#   'time',
#   'good',
#   'thing'],
#  ['realginnyrobin', 'yeah', 'mean'],
#  ['also', 'buy', 'manchest', 'unit', 'ur', 'welcom'],
#  ['grimezsz',
#   'downsid',
#   'elf',
#   'ear',
#   'surgeri',
#   'probabl',
#   'outweigh',
#   'upsid'],
#  ['clear',
#   'support',
#   'left',
#   'half',
#   'republican',
#   'parti',
#   'right',
#   'half',
#   'democrat',
#   'parti'],
#  ['yangliuxh', 'zichenwangher', 'reason', 'accur', 'translat'],
#  ['wholemarsblog', 'ok', 'turn'],
#  ['rationaletienn', 'muskunivers', 'reason', 'agre', 'guy', 'much'],
#  ['magic', 'moment'],
#  ['kristennetten', 'wonderofsci', 'shall'],
#  ['kristennetten', 'wonderofsci', 'seek', 'one', 'mar', 'bar', 'tomorrow'],
#  ['mom', 'import', 'career'],
#  ['highli', 'recommend', 'http', 'co', 'nrdz4gjqee'],
#  ['andst7', 'question', 'twitter', 'everyth', 'possibl', 'avoid', 'answer'],
#  ['sawyermerritt',
#   'icannot',
#   'enough',
#   'modifi',
#   'car',
#   'deliveri',
#   'legal',
#   'america',
#   'ye'],
#  ['icannot', 'enough', 'said', 'add', 'autoconfigur', 'side', 'mirror'],
#  ['icannot',
#   'enough',
#   'side',
#   'mirror',
#   'caus',
#   '5',
#   'rang',
#   'reduct',
#   'highway',
#   'speed'],
#  ['icannot',
#   'enough',
#   'ye',
#   'side',
#   'mirror',
#   'need',
#   'self',
#   'drive',
#   'futur'],
#  ['might', 'need', 'new', 'po', 'box', 'tweet'],
#  ['nice',
#   'letter',
#   'bill',
#   'nix',
#   'would',
#   'prof',
#   'stanford',
#   'put',
#   'grad',
#   'studi',
#   'perman',
#   'deferm',
#   'http',
#   'co',
#   'bqtz78w3y8'],
#  ['spacex',
#   'fair',
#   'half',
#   'fulli',
#   'capabl',
#   'reentri',
#   'vehicl',
#   'thruster',
#   'thermal',
#   'protect',
#   'avion',
#   'amp',
#   'sensor',
#   'suit'],
#  ['dilbert', 'daili', 'free', 'willi', 'never', 'free'],
#  ['still', 'grate', 'http', 'co', 'ehdyxw4fqn'],
#  ['teslaownerssv',
#   'cchomp13',
#   'mani',
#   'major',
#   'code',
#   'chang',
#   'extra',
#   'cautiou',
#   'rollout',
#   'releas',
#   'http',
#   'co',
#   'u0dpeq7sa'],
#  ['cchomp13', 'entropi'],
#  ['aelluswami',
#   'worth',
#   'hear',
#   'tesla',
#   'autopilot',
#   'softwar',
#   'ai',
#   'progress'],
#  ['wholemarsblog',
#   'mention',
#   'previous',
#   'major',
#   'releas',
#   'need',
#   'cautiou',
#   'goe',
#   '1000',
#   'beta',
#   'particip',
#   'later',
#   'today'],
#  ['neuralink',
#   'progress',
#   'updat',
#   'show',
#   'amp',
#   'tell',
#   'octob',
#   '31',
#   'st',
#   'halloween'],
#  ['2',
#   'main',
#   'goal',
#   'year',
#   'starship',
#   'orbit',
#   'fsd',
#   'wide',
#   'releas',
#   'mani',
#   'thing',
#   'cours',
#   '2',
#   'http',
#   'co',
#   'ikvpblkzjr'],
#  ['fastest',
#   'way',
#   'get',
#   'one',
#   'downtown',
#   'anoth',
#   'known',
#   'physic',
#   'standard',
#   'model',
#   'prove',
#   'quiet',
#   'resili'],
#  ['would',
#   'cool',
#   'much',
#   'simplifi',
#   'hyperloop',
#   'demo',
#   'tunnel',
#   'mayb',
#   'austin',
#   'amp',
#   'san',
#   'antonio'],
#  ['boringcompani',
#   'tunnel',
#   'activ',
#   'use',
#   'vega',
#   'tri',
#   'town',
#   'expand',
#   'connect',
#   'http',
#   'co',
#   '74aqxcakz4'],
#  ['funni',
#   'often',
#   'simultan',
#   'reaction',
#   'say',
#   'imposs',
#   'alreadi',
#   'done',
#   '3000',
#   'year',
#   'ago'],
#  ['chazman',
#   'aelluswami',
#   'glad',
#   'work',
#   'thank',
#   'give',
#   'u',
#   'tough',
#   'case',
#   'solv',
#   'field',
#   'testin',
#   'http',
#   'co',
#   'bqpzwuomml'],
#  ['chazman',
#   'aelluswami',
#   'want',
#   'emphas',
#   'awesom',
#   'tesla',
#   'softwar',
#   'ai',
#   'team',
#   'realli',
#   'deserv',
#   'http',
#   'co',
#   'sqb6slga8j'],
#  ['note', 'upgrad', 'exist', 'car', 'fsd', '2', 'min', 'via', 'tesla', 'app'],
#  ['wide',
#   'releas',
#   'fsd',
#   'beta',
#   '10',
#   '69',
#   '2',
#   'price',
#   'fsd',
#   'rise',
#   '15k',
#   'north',
#   'america',
#   'septemb',
#   '5th',
#   'current',
#   'http',
#   'co',
#   'ec7nxirjxg'],
#  ['fsd',
#   'beta',
#   '10',
#   '69',
#   'start',
#   'roll',
#   'tesla',
#   'owner',
#   'last',
#   'night',
#   'build',
#   'big',
#   'step',
#   'forward',
#   '10',
#   '69',
#   '1',
#   'probabl',
#   'http',
#   'co',
#   '9zn26seexg'],
#  ['blkmdl3',
#   'tesla',
#   'tesla',
#   'autopilot',
#   'ai',
#   'team',
#   'great',
#   'work',
#   '10',
#   '69',
#   'point',
#   'releas',
#   'need',
#   'polish',
#   '10',
#   '69',
#   '2',
#   'realli',
#   'shine'],
#  ['cours', 'civil', 'alway', 'upward', 'http', 'co', '8mr7pfwcni'],
#  ['heydave7', 'true'],
#  ['mechazilla', 'load', 'starship', 'launchpad', 'http', 'co', 'lfkfjpaczj'],
#  ['arctechinc',
#   '10',
#   '69',
#   'limit',
#   'releas',
#   'reason',
#   'plea',
#   'ask',
#   'includ',
#   'earli',
#   'beta',
#   'releas',
#   'complain'],
#  ['spam',
#   'preval',
#   'share',
#   'board',
#   'board',
#   'chose',
#   'disclos',
#   'public',
#   'http',
#   'co',
#   'lxk48tfzl1'],
#  ['andst7', 'import', 'thread'],
#  ['evafoxu', 'case', 'anyon', 'feel', 'like', 'buy', 'fine', 'whistl'],
#  ['alliyahsimstv', 'yet', 'anoth', 'verifi'],
#  ['id', 'aa', 'carmack', 'wake', 'morn'],
#  ['bbc', 'futur', 'would', 'gladli', 'obey', 'command', 'tell', 'say'],
#  ['rationaletienn',
#   'arctechinc',
#   'doubt',
#   'critic',
#   'public',
#   'privat',
#   'welcom',
#   'go',
#   'wide',
#   'beta',
#   'http',
#   'co',
#   'gg6cjgq1x'],
#  ['rationaletienn',
#   'arctechinc',
#   'let',
#   'make',
#   'someth',
#   'clear',
#   'jame',
#   'contact',
#   'directli',
#   'includ',
#   'earli',
#   'http',
#   'co',
#   'okarvaorrk'],
#  ['someth', 'special', 'http', 'co', 'lsmiryt8zf'],
#  ['think', 'global', 'warm', 'major', 'risk'],
#  ['mark', 'word'],
#  ['popul',
#   'collaps',
#   'due',
#   'low',
#   'birth',
#   'rate',
#   'much',
#   'bigger',
#   'risk',
#   'civil',
#   'global',
#   'warm'],
#  ['sciguyspac', 'good', 'summari'],
#  ['note',
#   'connect',
#   '2',
#   '4',
#   'mbit',
#   'per',
#   'cell',
#   'zone',
#   'work',
#   'great',
#   'text',
#   'amp',
#   'voic',
#   'call',
#   'high',
#   'bandwidth'],
#  ['starlink',
#   'v2',
#   'launch',
#   'next',
#   'year',
#   'transmit',
#   'direct',
#   'mobil',
#   'phone',
#   'elimin',
#   'dead',
#   'zone',
#   'worldwid'],
#  ['livestream', 'big', 'news', 'hour', 'http', 'co', 'lsmirybxhh'],
#  ['teslaownerssv',
#   '10',
#   '69',
#   '1',
#   'releas',
#   'monday',
#   'night',
#   '10',
#   '69',
#   '2',
#   'week',
#   'later',
#   'wide',
#   'beta',
#   'version'],
#  ['sawyermerritt', 'spacex', 'ron', 'barron', 'awesom'],
#  ['wholemarsblog', 'realdanodowd', 'crazi'],
#  ['renatakonkoli', 'caffein', 'one', 'troubl'],
#  ['skmorefield', 'inde', 'sadli', 'anti', 'human'],
#  ['countri',
#   'increas',
#   'nuclear',
#   'power',
#   'gener',
#   'insan',
#   'nation',
#   'secur',
#   'standpoint',
#   'amp',
#   'bad',
#   'http',
#   'co',
#   'nesjois0qm'],
#  ['icannot',
#   'enough',
#   'safe',
#   'say',
#   'output',
#   'exceed',
#   'mass',
#   'known',
#   'univers'],
#  ['id',
#   'aa',
#   'carmack',
#   'similarli',
#   'high',
#   'cycl',
#   'life',
#   'nickel',
#   'cathod',
#   'possibl',
#   'optim',
#   'ad',
#   'silicon',
#   'http',
#   'co',
#   'aowkcvk3b'],
#  ['billym2k', 'true'],
#  ['matchasmmatt',
#   'jasondebolt',
#   'heydave7',
#   'plu',
#   'pessim',
#   'futur',
#   'fals',
#   'overpopul',
#   'fear'],
#  ['plea',
#   'share',
#   'thing',
#   'thread',
#   'work',
#   'life',
#   'amp',
#   'other',
#   'may',
#   'find',
#   'help'],
#  ['cb', 'doge', 'northmantrad', 'yeah', 'lift', 'littl'],
#  ['northmantrad', '20', 'lb', 'unhealthi', 'peak', 'weight'],
#  ['time', 'time', 'share', 'thing', 'seem', 'work', 'case', 'find', 'help'],
#  ['zero', 'fast', 'app', 'quit', 'good'],
#  ['advic', 'good', 'friend', 'fast', 'period', 'amp', 'feel', 'healthier'],
#  ['nypost', 'ye', 'done', 'lot', 'place'],
#  ['bullsunvalley', 'culturaltutor', 'gnu', 'news', 'snooz'],
#  ['agiovanni', '1', 'culturaltutor', 'come'],
#  ['renatakonkoli', 'culturaltutor', 'are'],
#  ['culturaltutor',
#   'call',
#   'great',
#   'dane',
#   'eat',
#   'small',
#   'piec',
#   'ham',
#   'tini',
#   'villag',
#   'hamlet',
#   'eat',
#   'hamlet',
#   'http',
#   'co',
#   'mp2vei8ibh'],
#  ['squeez',
#   'extra',
#   'perform',
#   'falcon',
#   '9',
#   'almost',
#   '17',
#   'metric',
#   'ton',
#   'actual',
#   'use',
#   'orbit',
#   'booster',
#   'amp',
#   'fai',
#   'http',
#   'co',
#   '4lz6asvugm'],
#  ['culturaltutor', 'mayb', 'time', 'new', 'roman'],
#  ['slashdot', 'get', 'orbit', 'amp', 'back', 'harder', 'may', 'seem'],
#  ['muskunivers', 'true'],
#  ['teslaownerssv', 'spacex', 'ancient', 'time'],
#  ['teslaownerssv', 'grow', 'least', '5', '10', 'meter', 'time'],
#  ['wholemarsblog',
#   'first',
#   'day',
#   '1k',
#   'owner',
#   'go',
#   '10k',
#   'major',
#   'issu',
#   'note',
#   '10',
#   '69',
#   '2',
#   'hope',
#   'goin',
#   'http',
#   'co',
#   'twkmmiy5dx'],
#  ['muskunivers', 'good', 'ask', 'often'],
#  ['csi',
#   'starbas',
#   'agre',
#   'recent',
#   'made',
#   'chang',
#   'amp',
#   'mani',
#   'other',
#   'intens',
#   'effort',
#   'underway',
#   'achiev',
#   'robust',
#   'http',
#   'co',
#   'pczhtnzmqe'],
#  ['happen', 'matter', 'time', 'http', 'co', 'heyzhzbaih'],
#  ['godspe', 'artemi', 'http', 'co', '8rzsqpambf'],
#  ['renatakonkoli',
#   'kristennetten',
#   'culturaltutor',
#   'swoop',
#   'x',
#   'meant',
#   'repres',
#   'rocket',
#   'arc',
#   'orbit'],
#  ['jonbbc', 'hope', 'week'],
#  ['kristennetten',
#   'culturaltutor',
#   'somewhat',
#   'agon',
#   'tesla',
#   'amp',
#   'spacex',
#   'font',
#   'design',
#   'love',
#   'font',
#   'tbh',
#   'http',
#   'co',
#   'h0ezbrua7d'],
#  ['jgebbia', 'wise', 'action'],
#  ['hubermanlab', 'diet', 'coke', 'amaz'],
#  ['almost',
#   'hear',
#   'snap',
#   'rubber',
#   'glove',
#   'chess',
#   'match',
#   'caviti',
#   'search'],
#  ['version',
#   'occam',
#   'razor',
#   'entertain',
#   'outcom',
#   'like',
#   'http',
#   'co',
#   'zbwq2altnx'],
#  ['talent',
#   'hit',
#   'target',
#   'one',
#   'el',
#   'hit',
#   'geniu',
#   'hit',
#   'target',
#   'one',
#   'see',
#   'caus',
#   'ur',
#   'butt',
#   'schopenha',
#   'http',
#   'co',
#   'mcqgmdqsna'],
#  ['wholemarsblog',
#   'jonbbc',
#   'aelluswami',
#   '10',
#   '69',
#   '2',
#   'goe',
#   '100k',
#   'owner',
#   'next',
#   'week'],
#  ['spent',
#   'day',
#   'walk',
#   'entir',
#   'giga',
#   'berlin',
#   'product',
#   'line',
#   'team',
#   'excel',
#   'work'],
#  ['jonbbc',
#   'wholemarsblog',
#   'aelluswami',
#   '10',
#   '69',
#   '1',
#   'even',
#   'better',
#   'reduc',
#   'latenc',
#   'amp',
#   'jitter',
#   'hardwar',
#   'command',
#   'loop',
#   'http',
#   'co',
#   'sx96b23y1x'],
#  ['kickass',
#   'internet',
#   'connect',
#   'come',
#   'royal',
#   'caribbean',
#   'ship',
#   'soon',
#   'http',
#   'co',
#   '8qjriuunah'],
#  ['bot', 'basi', 'deal', 'awesom'],
#  ['sure', 'sound', 'higher', '5', 'http', 'co', 'va7txxzoi6'],
#  ['chriszheng001', 'intend', 'soon', 'possibl'],
#  ['sciguyspac', 'yeah', 'aim', '100', 'flight', 'next', 'year'],
#  ['launch', 'everi', '5', 'day', 'http', 'co', 'kjyg5ckpyx'],
#  ['michaelgr1011',
#   'lapdhq',
#   'rickcarusola',
#   'ericgarcetti',
#   'mayorofla',
#   'lapdvannuysdiv',
#   'hope',
#   'connor',
#   'ok'],
#  ['heydave7', 'moodi', 'irrelev'],
#  ['cb',
#   'doge',
#   'chrisrock',
#   'invit',
#   'open',
#   'one',
#   'show',
#   'thank',
#   'chri',
#   'tri',
#   'flounder',
#   'much'],
#  ['sirxapex', 'sciguyspac', 'ye', 'also', 'import'],
#  ['sciguyspac',
#   'accur',
#   'ass',
#   'raptor',
#   'design',
#   'start',
#   'use',
#   'h2',
#   'switch',
#   'ch4',
#   'latter',
#   'best',
#   'combo',
#   'http',
#   'co',
#   'iwrqwbsutl'],
#  ['andst7',
#   'import',
#   'south',
#   'korea',
#   'current',
#   'track',
#   'lose',
#   'half',
#   'popul',
#   'roughli',
#   'everi',
#   'gener',
#   'lo',
#   'http',
#   'co',
#   '0uywerxgwp'],
#  ['joshcarlosjosh',
#   'peter',
#   'jackson',
#   'excel',
#   'work',
#   'lord',
#   'ring',
#   'hobbit',
#   'stretch',
#   'long',
#   'short',
#   'book'],
#  ['sawyermerritt',
#   'tesla',
#   'suppli',
#   'low',
#   'order',
#   'powerwal',
#   'possibl',
#   'end',
#   'year'],
#  ['teslarati', 'johnnacrider1', 'cool'],
#  ['order',
#   'tesla',
#   'powerwal',
#   'batteri',
#   'blackout',
#   'protect',
#   'http',
#   'co',
#   'tee4ldbd78'],
#  ['90', 'comment', 'bot', 'http', 'co', 'a7rkynjzor'],
#  ['almost',
#   'everi',
#   'male',
#   'charact',
#   'far',
#   'coward',
#   'jerk',
#   'galadriel',
#   'brave',
#   'smart',
#   'nice'],
#  ['wholemarsblog',
#   'releas',
#   '10',
#   '69',
#   '2',
#   'probabl',
#   'end',
#   'week',
#   'need',
#   'bit',
#   'polish'],
#  ['tolkien', 'turn', 'grave'],
#  ['wholemarsblog',
#   '10',
#   '69',
#   '2',
#   'rel',
#   'small',
#   'number',
#   'code',
#   'chang',
#   'practic',
#   'effect',
#   'signific'],
#  ['spacex', 'starlink', 'reach', 'orbit'],
#  ['andst7', 'probabl', 'help', 'proportion', 'cost', 'rais', 'child'],
#  ['punni'],
#  ['wholemarsblog',
#   'solar',
#   'batteri',
#   'need',
#   'batteri',
#   'great',
#   'deal',
#   'peak',
#   'demand'],
#  ['lexfridman', 'accept', '99', 'cooki', 'choc', 'chip'],
#  ['garyblack00',
#   'twitter',
#   'put',
#   'much',
#   'effort',
#   'bot',
#   'spam',
#   'remov',
#   'subpoena',
#   'p',
#   'http',
#   'co',
#   'wubiybi3qc'],
#  ['garyblack00',
#   'advis',
#   'potenti',
#   'wit',
#   'provid',
#   'full',
#   'cooper',
#   'court',
#   'control',
#   'action'],
#  ['garyblack00',
#   'read',
#   'actual',
#   'rule',
#   'zero',
#   'david',
#   'sack',
#   'respons',
#   'zero'],
#  ['musicphantom69',
#   'claim',
#   'critic',
#   'ring',
#   'power',
#   'mean',
#   'racist',
#   'outing',
#   'closet',
#   'racist'],
#  ['blkmdl3',
#   'appl',
#   'spacex',
#   'promis',
#   'convers',
#   'appl',
#   'starlink',
#   'connect',
#   'iphon',
#   'team',
#   'http',
#   'co',
#   'slezqivtha'],
#  ['austinhinson',
#   'tesla',
#   'note',
#   'put',
#   'lot',
#   'time',
#   'person',
#   'advanc',
#   'tesla',
#   'servic',
#   'make',
#   'awesom',
#   'http',
#   'co',
#   'azyulrxjqp'],
#  ['austinhinson',
#   'right',
#   'credit',
#   'tesla',
#   'owner',
#   '100',
#   'chang',
#   'appoint',
#   'le',
#   '24',
#   'hour',
#   'n',
#   'http',
#   'co',
#   'xpsdkpf2li'],
#  ['teslaownerssv',
#   'lot',
#   'peopl',
#   'still',
#   'realiz',
#   'tesla',
#   'make',
#   'uninterrupt',
#   'power',
#   'suppli',
#   'whole',
#   'home',
#   'powerwal'],
#  ['rememb', 'http', 'co', 'unsjk0cjm9'],
#  ['da5i', 'thread', 'bring', 'back', 'lot', 'memori'],
#  ['ev',
#   'australia',
#   'tesla',
#   'sawyermerritt',
#   'evafoxu',
#   'miku919191',
#   'tesla',
#   'adri',
#   'ppathol',
#   'teslahyp',
#   'tesladiva99',
#   'http',
#   'co',
#   'ekeyb4tg3x'],
#  ['wholemarsblog',
#   'primari',
#   'solut',
#   'sustain',
#   'energi',
#   'futur',
#   'solar',
#   'wind',
#   'batteri',
#   'sun',
#   'http',
#   'co',
#   'xyucdpo9ix'],
#  ['wholemarsblog',
#   'fusion',
#   'would',
#   'expens',
#   'energi',
#   'given',
#   'difficulti',
#   'obtain',
#   'transport',
#   'sourc',
#   'fuel',
#   'plu',
#   'http',
#   'co',
#   '75xlnyfwxz'],
#  ['chicago',
#   'glenn',
#   '64',
#   'squar',
#   'fog',
#   'war',
#   'tech',
#   'tree',
#   'differ',
#   'piec',
#   'random',
#   'spawn',
#   'chess',
#   'http',
#   'co',
#   'xiovcb0ni'],
#  ['techmem', 'pkafka', 'interest'],
#  ['evasteslasplaid', 'paraga', 'bot', 'block', 'parti'],
#  ['codingmark',
#   'andy8671025',
#   'wholemarsblog',
#   'assum',
#   '25',
#   'effici',
#   'pv',
#   'cell',
#   '0',
#   '8',
#   'surfac',
#   'coverag'],
#  ['codingmark',
#   'andy8671025',
#   'wholemarsblog',
#   'exactli',
#   'ecosystem',
#   'almost',
#   'entir',
#   'depend',
#   'sun',
#   'alreadi',
#   'civil',
#   'http',
#   'co',
#   'isa18j1xss'],
#  ['csi',
#   'starbas',
#   'yup',
#   'reason',
#   'static',
#   'fire',
#   'much',
#   'better',
#   'break',
#   'thing',
#   'ground',
#   'en',
#   'rout',
#   'orbit'],
#  ['andy8671025',
#   'wholemarsblog',
#   'solar',
#   'panel',
#   'ground',
#   'mount',
#   'amp',
#   'rooftop',
#   'pair',
#   'stationari',
#   'batteri',
#   'civiliz',
#   'http',
#   'co',
#   'eadbvrpw'],
#  ['tesla', 'love', 'graffiti', 'art', 'giga', 'berlin'],
#  ['wholemarsblog',
#   'much',
#   'empti',
#   'land',
#   'amp',
#   'tini',
#   'percentag',
#   'need',
#   'power',
#   'entir',
#   'countri'],
#  ['wholemarsblog', 'look', 'good', 'far'],
#  ['evafoxu', 'inde'],
#  ['wholemarsblog',
#   'intern',
#   'beta',
#   'rollout',
#   'tonight',
#   'wider',
#   'tomorrow'],
#  ['wholemarsblog', 'come'],
#  ['take', 'materi', 'scienc', '101', 'regret'],
#  ['major', 'fed', 'rate', 'hike', 'risk', 'deflat'],
#  ['bennettm', 'plea', 'lmk', 'happen'],
#  ['teslagong',
#   'absolut',
#   'tesla',
#   'fleet',
#   'australia',
#   'grow',
#   'rapidli',
#   'need',
#   'ramp',
#   'servic',
#   'gener'],
#  ['tesla', 'north', 'america', 'aim', 'gt', '50', 'hour', 'servic'],
#  ['billym2k',
#   'cz',
#   'binanc',
#   'nice',
#   'dress',
#   'sink',
#   'amp',
#   'knock',
#   'random',
#   'door',
#   'see',
#   'http',
#   'co',
#   'ktehdkpg0a'],
#  ['spacex', 'one', 'complex', 'mission'],
#  ['falcon', 'arch', 'orbit', 'http', 'co', 'm7grug8fv9'],
#  ['obviou', 'limit', 'rocket', 'reflight', 'far', 'http', 'co', 'rbrcyjxjea'],
#  ['austen', 'instagram', 'envi', 'amplifi'],
#  ['wholemarsblog',
#   'team',
#   'found',
#   'bug',
#   'caus',
#   '8',
#   'delay',
#   'detect',
#   'pedestrian',
#   'gt',
#   '50m',
#   'fix',
#   'roll',
#   'tonight'],
#  ['chicago', 'glenn', 'stevenmarkryan', 'wholemarsblog', 'pretti', 'accur'],
#  ['astronomi'],
#  ['teslaownerssv',
#   'cb',
#   'doge',
#   'tesla',
#   'mayemusk',
#   'guess',
#   'could',
#   'make',
#   'joe',
#   'mode',
#   'quieter'],
#  ['cb', 'doge', 'tesla', 'mayemusk', 'still', 'thing', 'bigger'],
#  ['look', 'good', 'roll', 'tesla', 'owner', '10', '12', '2', '100k', 'car'],
#  ['tesla', 'mania', 'wholemarsblog', 'probabl', 'right', 'order', 'magnitud'],
#  ['wholemarsblog',
#   'real',
#   'world',
#   'valid',
#   'amp',
#   'billion',
#   'mile',
#   'real',
#   'world',
#   'train',
#   'make',
#   'fsd',
#   'superhuman'],
#  ['cb', 'doge', 'paraga', 'sigh'],
#  ['fsd',
#   'beta',
#   '10',
#   '69',
#   '2',
#   'roll',
#   'plea',
#   'note',
#   'top',
#   'prioriti',
#   'safeti',
#   'expect',
#   'overli',
#   'cautiou',
#   'esp',
#   'http',
#   'co',
#   '93fdpmob8l'],
#  ['hardcorehistori', 'appetit', 'infinit', 'number', 'interest', 'tweet'],
#  ['take', 'moment', 'http', 'co', 'r3hk5u4uw6'],
#  ['residu',
#   'valu',
#   'gasolin',
#   'car',
#   'bought',
#   'today',
#   'much',
#   'lower',
#   'peopl',
#   'think'],
#  ['evafoxu',
#   'supercharg',
#   'center',
#   'solar',
#   'amp',
#   'batteri',
#   'long',
#   'term',
#   'vision'],
#  ['long', 'view', 'gasolin', 'car', 'way', 'view', 'steam', 'engin', 'today'],
#  ['trimontiumtrust', 'hardcorehistori', 'socrat', 'littl', 'bore', 'tbh'],
#  ['ilyasut', 'view', 'realiti', 'alway', 'wrong', 'question', 'wrong'],
#  ['salt',
#   'butter',
#   'amaz',
#   'store',
#   'room',
#   'temperatur',
#   'http',
#   'co',
#   '8rsr340jb8'],
#  ['corey', 'aronson', 'cathiedwood', 'drop', '0', '25'],
#  ['cathiedwood', 'exactli', 'neither', 'subtl', 'secret'],
#  ['wholemarsblog',
#   'layer',
#   'upon',
#   'layer',
#   'neural',
#   'net',
#   'ever',
#   'higher'],
#  ['huobiglob', 'subtl'],
#  ['note', 'work', 'make', 'whistl', 'sound', 'much', 'louder'],
#  ['u', 'pay', 'doge'],
#  ['blow', 'whistl', 'http', 'co', 'rqldti0ulz'],
#  ['chrissyfarr', 'true'],
#  ['kimbal', 'could', 'wors'],
#  ['prasad',
#   's7',
#   'jgrupe',
#   'tesla',
#   'sawyermerritt',
#   'dirtytesla',
#   'fair',
#   'point'],
#  ['andst7', 'good', 'thread'],
#  ['tarabull808', 'sound', 'pretti', 'bad'],
#  ['plea', 'fix', 'twitter', 'verifi', 'paraga'],
#  ['tweet', 'suppress'],
#  ['say',
#   'none',
#   'member',
#   'stripe',
#   'chat',
#   'spoke',
#   'said',
#   'accept',
#   'payment',
#   'agr',
#   'http',
#   'co',
#   'fvknmt1pvm'],
#  ['anyon',
#   'know',
#   'secret',
#   'client',
#   'let',
#   'twitter',
#   'rn',
#   'haha',
#   'http',
#   'co',
#   'g8d1mqzlrv'],
#  ['johnarnoldfndtn', 'absolut'],
#  ['jgrupe', 'tesla', 'sawyermerritt', 'dirtytesla', 'true'],
#  ['teslahyp', 'test', 'today', 'palo', 'alto'],
#  ['rome', 'show', 'underappreci', 'http', 'co', 'oqd3b6o5mw'],
#  ['tesmanian', 'com', 'harder', 'reach', 'volum', 'product', 'insan', 'hard'],
#  ['gailalfaratx',
#   'tesla',
#   'aelluswami',
#   'beta',
#   'expand',
#   'safeti',
#   'score',
#   '80',
#   '10',
#   '69',
#   '2',
#   '1',
#   'goe'],
#  ['gailalfaratx',
#   'tesla',
#   'aelluswami',
#   '10',
#   '69',
#   '2',
#   '1',
#   'come',
#   'day',
#   'addit',
#   'polish',
#   '10',
#   '69',
#   '3',
#   'come',
#   'shortli',
#   'ai',
#   'day'],
#  ['ilyasut', 'short', 'short', 'http', 'co', 'ek4xby92ga'],
#  ['erikbryn',
#   'ericschmidt',
#   'condoleezzaric',
#   'scsp',
#   'ai',
#   'ukrain',
#   'hyperloop',
#   'could',
#   'trip',
#   'le',
#   'half',
#   'hour'],
#  ['rainmaker1973', 'look', 'like', 'fight', 'actual', 'fire', 'demon'],
#  ['help', 'mend', 'fault', 'star'],
#  ['larckeningxuruo',
#   'cb',
#   'doge',
#   'later',
#   'year',
#   'laser',
#   'link',
#   'activ',
#   'polar',
#   'constel'],
#  ['starlink', 'meant', 'peac', 'use'],
#  ['exposingbiden',
#   'musckid',
# ...
#   'utterli',
#   'nuclear',
#   'missil',
#   'le',
#   '30',
#   'minut',
#   'amp',
#   'http',
#   'co',
#   'w9ahiuutp5'],
#  ['nichegam', 'potenti'],
#  ['rschmi',
#   'spideycyp',
#   '155',
#   'sawyermerritt',
#   'spacex',
#   'internet',
#   'fiber',
#   'phone',
#   'line',
#   'cell',
#   'tower',
#   'amp',
#   'space',
#   'base',
#   'comm',
#   'http',
#   'co',
#   'g1pcj6frtv'],
#  ['fedorovmykhailo', 'thank', 'clarifi'],
#  ['stonksreddit',
#   'rschmi',
#   'spideycyp',
#   '155',
#   'sawyermerritt',
#   'spacex',
#   'starlink',
#   'primari',
#   'commun',
#   'system',
#   'http',
#   'co',
#   'fwvwvrq7sx'],
#  ['rschmi',
#   'spideycyp',
#   '155',
#   'sawyermerritt',
#   'spacex',
#   'big',
#   'differ',
#   'peac',
#   'comm',
#   'v',
#   'warfront',
#   'comm',
#   'starlink',
#   'http',
#   'co',
#   'ho0xxpklag'],
#  ['evafoxu', 'nobodi', 'really7', 'evakbartlett', 'concern'],
#  ['stillgray', 'citizen', 'nation', 'help', 'ukrain', 'list'],
#  ['ajtourvil',
#   'sure',
#   'reason',
#   'person',
#   'would',
#   'launch',
#   'nuclear',
#   'war',
#   'problem',
#   'logic',
#   'http',
#   'co',
#   'xwn27y2r6u'],
#  ['evakbartlett', 'list', 'real', 'url'],
#  ['chrisg',
#   'nsf',
#   'proceed',
#   'care',
#   'rud',
#   'pad',
#   'starship',
#   'progress',
#   'set',
#   'back',
#   '6',
#   'month'],
#  ['rainmaker1973', 'game', 'earth', 'get', 'hit', 'object', 'size'],
#  ['rainmaker1973', 'use', 'lot', 'rocketri'],
#  ['true', 'http', 'co', 'pwmxuvu2fc'],
#  ['rainmaker1973', 'everi', 'milliped', 'millennium'],
#  ['hardcorehistori', 'bring', 'back', 'outfit'],
#  ['karpathi', 'good', 'thread'],
#  ['fanci', 'game', 'meme', 'tenni', 'http', 'co', 'd9tqilg7nb'],
#  ['buy', 'burnt', 'hair', 'compani', 'dig', 'hole'],
#  ['chicago', 'glenn', 'read', 'goth', 'clown', 'lone'],
#  ['hear', 'dyslex', 'kbg', 'agent', 'pot', 'secret'],
#  ['venn',
#   'diagram',
#   'intersect',
#   'two',
#   'audienc',
#   'pretti',
#   'small',
#   'guess'],
#  ['popular', 'hope', 'sigh'],
#  ['pitch',
#   'idea',
#   'crossov',
#   'da',
#   'boot',
#   'amp',
#   'bos',
#   'babi',
#   'da',
#   'babi',
#   'hijink',
#   'high',
#   'sea',
#   'http',
#   'co',
#   'fiermsthp2'],
#  ['teslaownerssv', 'oldmordim', 'scratch', 'buff'],
#  ['oldmordim', 'mostli', 'accur'],
#  ['comment', 'thread', 'conspiraci', 'theorist', 'wet', 'dream'],
#  ['evafoxu', '7', 'year', 'ago'],
#  ['futurejurvetson',
#   'spacex',
#   'definit',
#   'one',
#   'strangest',
#   'meet',
#   'ever',
#   'experienc',
#   'adeoressi'],
#  ['kimdotcom',
#   'twitter',
#   'tri',
#   'hardest',
#   'de',
#   'escal',
#   'situat',
#   'obvious',
#   'fail'],
#  ['kimdotcom', 'twitter', 'damn', 'damn', 'guess', 'damn'],
#  ['sawyermerritt',
#   'starship',
#   'amp',
#   'next',
#   'gen',
#   'starlink',
#   'satellit',
#   'key',
#   'much',
#   'risk',
#   'lie',
#   'ahead',
#   'work',
#   'scale'],
#  ['raheemkassam', 'hilari', 'thing', 'wrong'],
#  ['evafoxu', 'goe'],
#  ['gainzy222', 'fate', 'love', 'ironi'],
#  ['davidsack', 'even', 'still', 'good', 'deed'],
#  ['hell',
#   'even',
#   'though',
#   'starlink',
#   'still',
#   'lose',
#   'money',
#   'amp',
#   'compani',
#   'get',
#   'billion',
#   'taxpay',
#   'http',
#   'co',
#   'zhrwmlxio3'],
#  ['brian',
#   'j',
#   'berger',
#   'dude',
#   'condit',
#   'anonym',
#   'spineless',
#   'coward',
#   'also',
#   'ignor',
#   'fool',
#   'star',
#   'http',
#   'co',
#   'wzh89bte2e'],
#  ['spideycyp',
#   '155',
#   'ppathol',
#   'ashleev',
#   'requir',
#   'lot',
#   'resourc',
#   'go',
#   'super',
#   'lockdown',
#   'mode',
#   'slow',
#   'http',
#   'co',
#   'wqbutwfko1'],
#  ['ashleev',
#   'dod',
#   'provid',
#   '3',
#   'falcon',
#   '1',
#   'develop',
#   'cost',
#   'appreci',
#   'certainli',
#   'seen',
#   'context'],
#  ['ppathol',
#   'ashleev',
#   'cours',
#   'signal',
#   'jam',
#   'system',
#   'also',
#   'get',
#   'better'],
#  ['ashleev',
#   'amount',
#   'spacex',
#   'request',
#   'major',
#   'battlefield',
#   'advantag',
#   'le',
#   'cost',
#   'one',
#   'new',
#   'gp',
#   'http',
#   'co',
#   'kocet6wu7'],
#  ['ajtourvil',
#   'would',
#   'great',
#   'someday',
#   'human',
#   'stop',
#   'point',
#   'nuke',
#   'would',
#   'destroy',
#   'almost',
#   'life',
#   'http',
#   'co',
#   'xlihnibjgn'],
#  ['starrski71',
#   'renatakonkoli',
#   'evafoxu',
#   'kadubai11',
#   'spideycyp',
#   '155',
#   'wrong',
#   'analog',
#   'america',
#   'also',
#   'humili',
#   'withdra',
#   'http',
#   'co',
#   'yla5asen5b'],
#  ['ppathol', 'spideycyp', '155', 'probabl'],
#  ['zerohedg', 'practic', 'make', 'perfect'],
#  ['renatakonkoli',
#   'evafoxu',
#   'kadubai11',
#   'spideycyp',
#   '155',
#   'russia',
#   'punch',
#   'nose',
#   'forc',
#   'retreat',
#   'mani',
#   'ti',
#   'http',
#   'co',
#   'qqws2xizad'],
#  ['kadubai11',
#   'spideycyp',
#   '155',
#   'obvious',
#   'mani',
#   'disagre',
#   'logic',
#   'think',
#   'probabl',
#   'b',
#   'http',
#   'co',
#   'ossdmvwvki'],
#  ['kadubai11',
#   'spideycyp',
#   '155',
#   'hey',
#   'look',
#   'bright',
#   'side',
#   'least',
#   'russia',
#   'get',
#   'crimea',
#   'scenario',
#   'http',
#   'co',
#   'jrp38qgthm'],
#  ['kadubai11',
#   'spideycyp',
#   '155',
#   'russia',
#   'face',
#   'destruct',
#   'armi',
#   'utter',
#   'defeat',
#   'nato',
#   'use',
#   'nuke',
#   'http',
#   'co',
#   'obklravgk7'],
#  ['spideycyp',
#   '155',
#   'whether',
#   'one',
#   'like',
#   'crimea',
#   'absolut',
#   'seen',
#   'core',
#   'part',
#   'russia',
#   'russia',
#   'crimea',
#   'http',
#   'co',
#   'wyeew1qudu'],
#  ['hyiki22', 'spideycyp', '155', 'exactli'],
#  ['spideycyp',
#   '155',
#   'russia',
#   'face',
#   'choic',
#   'lose',
#   'crimea',
#   'use',
#   'battlefield',
#   'nuke',
#   'choos',
#   'http',
#   'co',
#   'u6ezc1drqt'],
#  ['except', 'well', 'said', 'http', 'co', 'ut8fxg0mef'],
#  ['rhens',
#   'keith',
#   'dorschner',
#   'teslaownerssv',
#   'standard',
#   'non',
#   'perform',
#   '3',
#   'amp',
#   'suspens',
#   'product',
#   'improv',
#   'http',
#   'co',
#   'rpz72xxjnc'],
#  ['drknowitall16',
#   'pirate3guy',
#   'hserunjogi',
#   'yeah',
#   'rv',
#   'version',
#   'lower',
#   'prioriti',
#   'standard',
#   'version',
#   'still',
#   'http',
#   'co',
#   '8k0c6oxcv3'],
#  ['ok', 'add', 'donat', 'option', 'starlink'],
#  ['pirate3guy', 'hserunjogi', 'oddli', 'low', 'normal', 'much', 'higher'],
#  ['other',
#   'want',
#   'donat',
#   'starlink',
#   'place',
#   'need',
#   'http',
#   'co',
#   'm0asmenmrd'],
#  ['dogecoinnorway', 'moxi', 'id', 'aa', 'carmack', 'happen', 'mani', 'time'],
#  ['moxi',
#   'id',
#   'aa',
#   'carmack',
#   'much',
#   'quieter',
#   'leaf',
#   'blower',
#   'possibl'],
#  ['teslaownerssv', 'harder', 'sound', 'ok'],
#  ['teslaownerssv', 'actual', 'smart', 'summon', 'almost', 'done'],
#  ['stoolpresident', 'plan'],
#  ['teslaaibot', 'spacex', 'tesla', 'thank', 'optimu'],
#  ['sawyermerritt',
#   'spacex',
#   'precis',
#   '25',
#   '300',
#   'termin',
#   'sent',
#   'ukrain',
#   'present',
#   '10',
#   '630',
#   'pay',
#   'servic'],
#  ['sawyermerritt',
#   'spacex',
#   'spacex',
#   'alreadi',
#   'withdrawn',
#   'request',
#   'fund'],
#  ['dirtytesla', 'awesom'],
#  ['even',
#   'starlink',
#   'video',
#   'call',
#   'one',
#   'airplan',
#   'aloft',
#   'starlink',
#   'anoth',
#   'far',
#   'away',
#   'airplan',
#   'aloft',
#   'wor',
#   'http',
#   'co',
#   'oxpcdh8vfq'],
#  ['chazman',
#   'aelluswami',
#   'sever',
#   'major',
#   'architectur',
#   'upgrad',
#   '10',
#   '69',
#   '3',
#   'much',
#   'point',
#   'releas',
#   'w',
#   'http',
#   'co',
#   'h9e51glezm'],
#  ['billym2k', 'atrupar', 'sound', 'fair'],
#  ['billym2k', 'definit', 'give', 'kid', 'name', 'idea'],
#  ['sold'],
#  ['internet',
#   'airplan',
#   'feel',
#   'access',
#   'internet',
#   'home',
#   'http',
#   'co',
#   'mfl2ixynjh'],
#  ['28',
#   '700',
#   'bottl',
#   'exquisit',
#   'burnt',
#   'hair',
#   'perfum',
#   'alreadi',
#   'sold',
#   '1',
#   '300',
#   'left',
#   'uniqu',
#   'limit',
#   'edit',
#   'col',
#   'http',
#   'co',
#   'idqanlrfs0'],
#  ['cb',
#   'doge',
#   'alex',
#   'avoigt',
#   'work',
#   'hope',
#   'releas',
#   'someth',
#   'next',
#   'week'],
#  ['alex',
#   'avoigt',
#   'money',
#   'dod',
#   'sever',
#   'countri',
#   'org',
#   'amp',
#   'individu',
#   'pay',
#   '11k',
#   '25k',
#   'termin',
#   'http',
#   'co',
#   'my3gnxioqh'],
#  ['atrupar', 'smart', 'mayb', 'dumb', 'stuff', 'definit'],
#  ['balaji', 'true'],
#  ['520alrihla', 'exactli'],
#  ['larryronaldpar1', 'make', 'weapon', 'ideal'],
#  ['teslahyp', 'easi', 'predict'],
#  ['drone', 'war', 'http', 'co', 'ervme0cbbn'],
#  ['neuro', 'skeptic'],
#  ['marenkahnert', 'jasondebolt', 'exactli'],
#  ['teslarati',
#   '13ericralph31',
#   'spacex',
#   'activ',
#   'satellit',
#   'orbit',
#   'rest',
#   'earth',
#   'combin',
#   'track',
#   'doubl',
#   'rest',
#   'earth',
#   'soon'],
#  ['jasondebolt',
#   'medium',
#   'report',
#   'great',
#   'fanfar',
#   'predict',
#   'late',
#   'rare',
#   'come',
#   'earli'],
#  ['teslarati',
#   'johnnacrider1',
#   'acceler',
#   'sustain',
#   'energi',
#   'primari',
#   'mission'],
#  ['westcoastbil', 'requir', 'truli', 'except', 'execut', 'possibl'],
#  ['let', 'matter', 'take'],
#  ['lifeboathq', 'right', 'eventu', 'run', 'time', 'http', 'co', 'gyxk9uzliw'],
#  ['giga',
#   'berlin',
#   'make',
#   'color',
#   'paint',
#   'shop',
#   'special',
#   'built',
#   'appli',
#   'mani',
#   'fine',
#   'layer',
#   'paint',
#   'givin',
#   'http',
#   'co',
#   'dx702xercn'],
#  ['teslaownerssv',
#   'billym2k',
#   'vari',
#   'lot',
#   'tesla',
#   'amp',
#   'spacex',
#   'good',
#   'posit',
#   'mani',
#   'compani',
#   'http',
#   'co',
#   'psemyxd9bg'],
#  ['renatakonkoli',
#   'thorstenbasch',
#   'spideycyp',
#   '155',
#   'billym2k',
#   'want',
#   'putin',
#   'remov',
#   'labor',
#   'misappr',
#   'http',
#   'co',
#   'jzy4zcenzt'],
#  ['thorstenbasch',
#   'spideycyp',
#   '155',
#   'billym2k',
#   'russia',
#   'overrun',
#   'ukrain',
#   'would',
#   'destabil',
#   'entir',
#   'region',
#   'perhap',
#   'world'],
#  ['spideycyp',
#   '155',
#   'billym2k',
#   'russia',
#   'face',
#   'calamit',
#   'defeat',
#   'convent',
#   'warfar',
#   'someth',
#   'strateg',
#   'c',
#   'http',
#   'co',
#   'zpxyv0ef5a'],
#  ['jamesplloyd', 'spacex', 'ye'],
#  ['spideycyp',
#   '155',
#   'billym2k',
#   'still',
#   'unlik',
#   'closest',
#   'sinc',
#   'cuba',
#   '62'],
#  ['teslaownerssv', 'billym2k', 'guess', 'probabl', 'spring', '24'],
#  ['billym2k',
#   'sure',
#   'would',
#   'nice',
#   'one',
#   'year',
#   'without',
#   'horribl',
#   'global',
#   'event'],
#  ['andrewperpetua', 'brutal', 'side', 'common', 'phrase', 'month', 'come'],
#  ['bgarlinghous', 'way'],
#  ['samitofp', 'mayb'],
#  ['newsfromsci', 'certainli', 'warrant', 'closer', 'scrutini'],
#  ['medvedevrussia', 'trussliz', 'btw', 'go', 'bakhmut'],
#  ['medvedevrussia', 'trussliz', 'pretti', 'good', 'troll', 'tbh'],
#  ['ilyasut', 'agre'],
#  ['alan', 'mcguin', 'british', 'humor', 'best'],
#  ['ppathol',
#   'evafoxu',
#   'davidsack',
#   'compromis',
#   'overwhelmingli',
#   'like',
#   'outcom',
#   'question',
#   'much',
#   'http',
#   'co',
#   'gwwchxt0zc'],
#  ['gaborgurbac', 'evafoxu', 'davidsack', 'natur', 'debat'],
#  ['evafoxu',
#   'davidsack',
#   'probabl',
#   'outcom',
#   'far',
#   'horribl',
#   'war',
#   'attrit',
#   'destroy',
#   'ukrain',
#   'amp',
#   'sever',
#   'http',
#   'co',
#   '5gjsm96ulz'],
#  ['davidsack', 'exactli'],
#  ['congrat',
#   'spacex',
#   'team',
#   '48th',
#   'launch',
#   'year',
#   'falcon',
#   '9',
#   'hold',
#   'record',
#   'launch',
#   'singl',
#   'vehicl',
#   'type',
#   'year'],
#  ['hillaryclinton',
#   'tini',
#   'possibl',
#   'might',
#   'stori',
#   'meet',
#   'eye',
#   'http',
#   'co',
#   'hcaf5drrjp'],
#  ['muskqu0t', 'happen'],
#  ['davidsack', 'theatlant', 'davidfrum', 'eliotacohen', 'hear', 'hear'],
#  ['ruthbenghiat',
#   'perpetu',
#   'propaganda',
#   'concoct',
#   'oil',
#   'amp',
#   'ga',
#   'industri',
#   'distract',
#   '6',
#   'tr',
#   'http',
#   'co',
#   '9uejbhqqab'],
#  ['stillgray',
#   'davidsack',
#   'switzerland',
#   'amp',
#   'belgium',
#   'great',
#   'chocol',
#   'also',
#   'love',
#   'eccentr',
#   'british',
#   'amp',
#   'irish',
#   'artisan',
#   'sweet',
#   'shop'],
#  ['davidsack', 'good', 'thread'],
#  ['teslaownerssv',
#   'next',
#   'week',
#   'actual',
#   'major',
#   'releas',
#   'lot',
#   'intern',
#   'test',
#   'need',
#   'go',
#   'public',
#   'beta'],
#  ['ksadjadpour', 'cool'],
#  ['davidsack',
#   'although',
#   'could',
#   'r',
#   'amp',
#   'candi',
#   'tbh',
#   'feel',
#   'like',
#   'much',
#   'improv',
#   'decad'],
#  ['wholemarsblog',
#   'headlin',
#   'mislead',
#   'starlink',
#   'obvious',
#   'offer',
#   'far',
#   'robust',
#   'posit',
#   'gp',
#   'wil',
#   'http',
#   'co',
#   'frslqsyy36'],
#  ['eigenrobot',
#   'one',
#   'favorit',
#   'conspiraci',
#   'theori',
#   'world',
#   'actual',
#   '80',
#   'men'],
#  ['chessproblem', 'un', 'as', 'ailabl', 'logic'],
#  ['pcgamer', 'great', 'game'],
#  ['mayb', 'social', 'medium', 'algorithm', 'even', 'peopl'],
#  ['think', 'might', 'decid', 'current', 'thing', 'accept'],
#  ['decid', 'current', 'thing', 'real', 'question', 'know'],
#  ['andst7', 'exactli', 'wapo', 'hypocrit'],
#  ['neuralink', 'show', 'amp', 'tell', 'nov', '30'],
#  ['muskqu0t', 'spacex', 'done'],
#  ['gfilch', 'martinviecha', 'come', 'long', 'way'],
#  ['know', 'noth', 'forev'],
#  ['michaelmalic', 'washingtonpost', 'good', 'point'],
#  ['muskunivers', 'need', 'chang', 'manufactur', 'awesom'],
#  ['gunsnrosesgirl3',
#   'dolphindronedom',
#   'excit',
#   'aliv',
#   'time',
#   'largest',
#   'anim',
#   'ever',
#   'wild',
#   'http',
#   'co',
#   'xf1olu9izi'],
#  ['fedorovmykhailo', 'teslarati', 'writer', '01001101', 'welcom'],
#  ['teslarati',
#   'writer',
#   '01001101',
#   'dod',
#   'even',
#   'came',
#   'back',
#   'answer',
#   'told',
#   'fedorovmykhailo',
#   'spacex',
#   'would',
#   'http',
#   'co',
#   'zydrar6mxf'],
#  ['lordofea',
#   'kerrikgray',
#   'chicago',
#   'glenn',
#   'tesla',
#   'teslaownerssv',
#   'dvorahfr',
#   'tonyadevitti',
#   'spacex',
#   'sirineati',
#   'absolut'],
#  ['skmorefield', 'interest'],
#  ['chazman', 'lexfridman', 'fast', 'rock'],
#  ['vitalikbuterin',
#   'balaji',
#   'zengjiajun',
#   'eth',
#   'doubl',
#   'take',
#   'first',
#   'non',
#   'fake',
#   'vitalik',
#   'tweet',
#   'seen'],
#  ['garyblack00',
#   'sawyermerritt',
#   'one',
#   'man',
#   'hedg',
#   'anoth',
#   'man',
#   'shrub'],
#  ['emollick', 'true'],
#  ['elon', 'wisdom', 'much', 'respect', 'author', 'inhibit', 'innov'],
#  ['lesson', 'took', 'longest', 'unlearn'],
#  ['swipewright',
#   'twitter',
#   'broadli',
#   'inclus',
#   'possibl',
#   'serv',
#   'fair',
#   'forum',
#   'live',
#   'even',
#   'occasi',
#   'http',
#   'co',
#   'ugirkhx2au'],
#  ['muskunivers', 'absolut', 'necessari'],
#  ['muskunivers', 'import'],
#  ['davidsack', 'exactli'],
#  ['vinnylingham', 'yeah', 'make', 'sen'],
#  ['muskunivers', 'good', 'thread'],
#  ['renatakonkoli',
#   'spideycyp',
#   '155',
#   'squawkcnbc',
#   'kasparov63',
#   'play',
#   'crazi',
#   '9'],
#  ['marcushous',
#   'lordofea',
#   'kerrikgray',
#   'chicago',
#   'glenn',
#   'tesla',
#   'teslaownerssv',
#   'dvorahfr',
#   'tonyadevitti',
#   'spacex',
#   'sirineati',
#   'http',
#   'co',
#   'ihgwe8askk'],
#  ['chananbo',
#   'squawkcnbc',
#   'kasparov63',
#   'yeah',
#   'back',
#   'spare',
#   'bedroom',
#   'couch',
#   'surf',
#   'friend',
#   'hous',
#   'silicon',
#   'val',
#   'http',
#   'co',
#   'xfrhrl0ren'],
#  ['spideycyp',
#   '155',
#   'squawkcnbc',
#   'kasparov63',
#   'child',
#   'found',
#   'simpl',
#   'use',
#   'real',
#   'life',
#   'http',
#   'co',
#   'e8b4pxjp9n'],
#  ['squawkcnbc',
#   'kasparov63',
#   'even',
#   'hous',
#   'let',
#   'alon',
#   'mansion',
#   'douch'],
#  ['squawkcnbc',
#   'kasparov63',
#   'true',
#   'kasparov',
#   'almost',
#   'good',
#   'play',
#   'chess',
#   'iphon',
#   'otherwis',
#   'idiot'],
#  ['sandyleevinc', 'nobodi', 'bat', '1000'],
#  ['beauti',
#   'thing',
#   'twitter',
#   'empow',
#   'citizen',
#   'journal',
#   'peopl',
#   'abl',
#   'dissemin',
#   'news',
#   'without',
#   'establish',
#   'bia'],
#  ['teslaownerssv', 'big', 'fan', 'citizen', 'journal'],
#  ['accord', 'unnam', 'sourc', 'close', 'matter', 'wish', 'remain', 'anonym'],
#  ['new',
#   'york',
#   'time',
#   'emerg',
#   'new',
#   'chaotic',
#   'actor',
#   'global',
#   'polit',
#   'paper',
#   'intervent',
#   'th',
#   'http',
#   'co',
#   '8tyloh5dut'],
#  ['westcoastbil', '30', 'lot'],
#  ['eldsjal', 'concern'],
#  ['work', 'move', 'land', 'object', 'http', 'co', 'xu4qkjw4d9'],
#  ['zubymus', 'absolut'],
#  ['dear', 'twitter', 'advertis', 'http', 'co', 'gmwhminpa'],
#  ['meet', 'lot', 'cool', 'peopl', 'twitter', 'today'],
#  ['enter', 'twitter', 'hq', 'let', 'sink', 'http', 'co', 'd68z4k2wq7'],
#  ['arodtv',
#   'definit',
#   'closer',
#   'citizen',
#   'journal',
#   'local',
#   'news',
#   'org',
#   'appreci',
#   'amp',
#   'get',
#   'way',
#   'promin',
#   'twitter'],
#  ['rpsagainsttrump',
#   'ye',
#   'account',
#   'restor',
#   'twitter',
#   'acquisit',
#   'consult',
#   'inform'],
#  ['twitter',
#   'form',
#   'content',
#   'moder',
#   'council',
#   'wide',
#   'diver',
#   'viewpoint',
#   'major',
#   'content',
#   'decis',
#   'http',
#   'co',
#   'gootqolydq'],
#  ['skorusark', 'cool'],
#  ['wearecanproud', 'first', 'heard'],
#  ['let', 'good', 'time', 'roll'],
#  ['catturd2', 'dig', 'today'],
#  ['bird', 'freed'],
#  ...]

# %% [markdown]
# ### Implementing Word2Vec Model by Gensim

# %%
model = Word2Vec(sentences=tweetList, min_count=1, vector_size=100, workers=4, window=4,sg=0)

# %%
similarWords = model.wv.most_similar('wonder', topn=5)  # get other similar words
similarWords
# Out:
# [('data', 0.5848771929740906),
#  ('lol', 0.5823049545288086),
#  ('ad', 0.5750864148139954),
#  ('real', 0.5685648322105408),
#  ('time', 0.5676756501197815)]

# %% [markdown]
# References:- Gensim Word2Vec Implementation by Medium
