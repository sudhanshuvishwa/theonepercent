# %% [markdown]
# # Experiment - 7 Logistic Regression on Spam Dataset

# %% [markdown]
# ###   Importing dependencies

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# Importing data

# %%
data = pd.read_csv('spam.csv', encoding='latin-1')

# %%
data.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %% [markdown]
# Dropping unncessary columns

# %%
data = data[['v1', 'v2']]

# %%
data.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# Renaming Columns

# %%
data.rename(columns={'v1': 'target', 'v2': 'text'}, inplace=True)

# %%
data.head()
# Out:
#   target                                               text
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  5572 non-null   object
#  1   text    5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
data.describe()
# Out:
#        target                    text
# count    5572                    5572
# unique      2                    5169
# top       ham  Sorry, I'll call later
# freq     4825                      30

# %% [markdown]
# #   Distribution of data

# %%
sns.countplot(x = data['target'])
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %% [markdown]
# Data Distribution is not balanced

# %%
data.shape
# Out:
# (5572, 2)

# %% [markdown]
# Removing Null Values

# %%
data.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %% [markdown]
# No null values

# %%
data.shape
# Out:
# (5572, 2)

# %% [markdown]
# Removing Duplicates

# %%
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (5169, 2)

# %% [markdown]
# Now creating a Character Length column for each text

# %%
data["length"] = data["text"].apply(lambda x: len(x))

# %%
data.head()
# Out:
#   target                                               text  length
# 0    ham  Go until jurong point, crazy.. Available only ...     111
# 1    ham                      Ok lar... Joking wif u oni...      29
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...     155
# 3    ham  U dun say so early hor... U c already then say...      49
# 4    ham  Nah I don't think he goes to usf, he lives aro...      61

# %% [markdown]
# Plotting spam vs ham Outliners on the basis of Character Length

# %%
g = data.pivot(columns="target", values="length").iplot(kind="box", asFigure=True, boxpoints='outliers')
g.update_layout(
    width=800,
    height=600,
)
# Out:
# <div>                            <div id="12eaa681-5060-485c-bb6f-abe12ed79a89" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("12eaa681-5060-485c-bb6f-abe12ed79a89")) {                    Plotly.newPlot(                        "12eaa681-5060-485c-bb6f-abe12ed79a89",                        [{"boxpoints":"outliers","line":{"width":1.3},"marker":{"color":"rgba(255, 153, 51, 1.0)"},"name":"ham","orientation":"v","y":[111.0,29.0,null,49.0,61.0,null,77.0,160.0,null,null,109.0,null,null,196.0,35.0,null,26.0,81.0,58.0,null,41.0,49.0,53.0,88.0,57.0,144.0,30.0,134.0,75.0,64.0,130.0,189.0,29.0,84.0,null,123.0,47.0,28.0,27.0,155.0,82.0,142.0,null,19.0,72.0,32.0,45.0,31.0,67.0,148.0,58.0,124.0,80.0,291.0,null,76.0,null,34.0,22.0,40.0,108.0,48.0,25.0,56.0,110.0
# ...

# %% [markdown]
# Length of Ham messages lie between 2-180, averaging at 52.
# Length of spam messages lie between 13-224, averaging at 149.
# Therefore We know that spam messages generally are longer.

# %% [markdown]
# #   Pre-processing

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import string
import re

# %%
data.loc[3008].text
# Out:
# 'Update_Now - 12Mths Half Price Orange line rental: 400mins...Call MobileUpd8 on 08000839402 or call2optout=J5Q'

# %%
text = 'Update_Now - 12Mths Half Price Orange line rental: 400mins...Call MobileUpd8 on 08000839402 or call2optout=J5Q'
text = text.lower()
text
# Out:
# 'update_now - 12mths half price orange line rental: 400mins...call mobileupd8 on 08000839402 or call2optout=j5q'

# %% [markdown]
# Removing punctuations and numbers

# %%
text = re.sub(r'[^a-zA-Z\s]', ' ', text)
text
# Out:
# 'update now     mths half price orange line rental     mins   call mobileupd  on             or call optout j q'

# %% [markdown]
# Tokenizing and Removing Stopwords then performing Lemmatization

# %%
words = nltk.word_tokenize(text)
stopword = stopwords.words("english")
words = [word for word in words if word not in stopword]
lemmatizer = WordNetLemmatizer()
words = [lemmatizer.lemmatize(word, pos="v") for word in words]
" ".join(words)
# Out:
# 'update mths half price orange line rental mins call mobileupd call optout j q'

# %%
def pre_process(text):
    
    text = text.lower()
    text = re.sub(r'[^a-zA-Z\s]', ' ', text)

    words = nltk.word_tokenize(text)
    stopword = stopwords.words("english")
    words = [word for word in words if word not in stopword]
    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(word, pos="v") for word in words]
    
    text = " ".join(words)
    
    return text

# %%
data["text"] = data["text"].apply(lambda x: pre_process(x))

# %%
data.head()
# Out:
#   target                                               text  length
# 0    ham  go jurong point crazy available bugis n great ...     111
# 1    ham                              ok lar joke wif u oni      29
# 2   spam  free entry wkly comp win fa cup final tkts st ...     155
# 3    ham                u dun say early hor u c already say      49
# 4    ham                nah think go usf live around though      61

# %% [markdown]
# #### Importing tfidf vectorizer

# %%
from sklearn.feature_extraction.text import TfidfTransformer, TfidfVectorizer, CountVectorizer

# %%
from sklearn.model_selection import train_test_split
X = data["text"]
y = data["target"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# %%
bow = CountVectorizer()
X_train_vec = bow.fit_transform(X_train)

# %% [markdown]
# Applying Logistic Regression on the dataset

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
# train a Logistic Regression Model
model = LogisticRegression()

# %%
model.fit(X_train_vec, y_train)
# Out:
# LogisticRegression()

# %%
X_test_vec = bow.transform(X_test)

# %%
y_pred = model.predict(X_test_vec)

# %%
y_pred
# Out:
# array(['spam', 'ham', 'spam', ..., 'spam', 'ham', 'ham'], dtype=object)

# %%
acc = accuracy_score(y_test, y_pred)
print("Accuracy:", acc*100)
# Out:
# Accuracy: 96.96969696969697

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

import seaborn as sns
sns.heatmap(cm, annot=True)
# Out:
# <Axes: >

# %%
cm
# Out:
# array([[1340,    3],
#        [  44,  164]], dtype=int64)

# %% [markdown]
# Classification of the Spam Dataset

# %%
from sklearn.metrics import classification_report
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.97      1.00      0.98      1343
#         spam       0.98      0.79      0.87       208
#
#     accuracy                           0.97      1551
#    macro avg       0.98      0.89      0.93      1551
# weighted avg       0.97      0.97      0.97      1551
